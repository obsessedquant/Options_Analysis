# %% [markdown]
# # Options Screener
#
# This notebook is meant to analyze a list of tickers and output which tickers have the highest value call options with the highest probability of increasing in value in the short-term.
#
# Manual steps procedure:
# - Update options_list2.csv with the latest OI pct changes from Optionistics.com using the options_list_compare.xlsx file
# - Get the latest finviz file from the local directory
#
# This screener looks at the following attributes:
# - Whether an option is 'cheap' i.e. has low realized volatility compared to its historical realized volatility, the lowest 15% are given a point
# - Implied volatility premium or discount, the top 15% are given a point
# - Open interest % change from optionistics, these are given a point
# - Highest float short percent, the top 15% are given a point

# %% [markdown]
# ### REMEMBER TO UPDATE THE OPTIONS_LIST2.CSV MANUALLY, BE SURE TO LOG IN FIRST.

# %%
# %matplotlib inline

import math
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
import time

tic = time.perf_counter()

# %%
import pandas as pd

tickers_df = pd.read_csv('../0_inputs/asset_screeners/options_list1.csv')
# optionistics_data = pd.read_csv('../0_inputs/asset_screeners/options_list2.csv')
# optionistics_data.head(3)

ticker_dictionary = {
    'VIX':'^VIX'
}

# ticker_list_df = pd.merge(tickers_df[['ticker']],optionistics_data[['ticker']],on='ticker',how='outer')

ticker_list = tickers_df['ticker'].to_list()

# %%
def realized_vol(price_data, window=30):
    log_return = (price_data["Close"] / price_data["Close"].shift(1)).apply(np.log)
    return log_return.rolling(window=window, center=False).std() * math.sqrt(252)

# %%
# windows = [30, 60, 90, 120] # calendar days
windows = [22, 44, 66, 88] # trading days
quantiles = [0.25, 0.75]

min_ = []
max_ = []
median = []
top_q = []
bottom_q = []
realized = []

# %%
completed_tkr_list = []
realized_vol_list = []
avg_pct_list = []
pct30_list = []
pct60_list = []
pct90_list = []
pct120_list = []
counter = 1

cur_price_dict = {}

# ticker_list = ['AAPL','TSLA','MSFT'] # test list

for ticker in ticker_list:

    print(f"Processing {ticker}, {counter} of {len(ticker_list)}...")
    
    try:
        # data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")

        # start="2020-01-01", end="2020-12-31"

        # start_date = '2020-01-01'
        # end_date = '2020-12-31'

        if ticker in ticker_dictionary:
            tkr = ticker_dictionary[ticker]
        else: tkr = ticker

        data = yf.download(  # or pdr.get_data_yahoo(...
                # tickers list or string as well
                tickers = tkr,

                # use "period" instead of start/end
                # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
                # (optional, default is '1mo')
                period = "1y",

        #         start = start_date,
        #         end = end_date,

                # fetch data by interval (including intraday if period < 60 days)
                # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
                # (optional, default is '1d')
                interval = "1d",

                # group by ticker (to access via data['SPY'])
                # (optional, default is 'column')
                group_by = 'ticker',

                # adjust all OHLC automatically
                # (optional, default is False)
                auto_adjust = True,

                # download pre/post regular market hours data
                # (optional, default is False)
                prepost = True,

                # use threads for mass downloading? (True/False/Integer)
                # (optional, default is True)
                threads = True,

                # proxy URL scheme use use when downloading?
                # (optional, default is None)
                proxy = None
            )

        # data.to_csv('BTC_1hr_prices.csv')
        # data.head(3)
    #     print(data.tail(5))

        cur_price_dict[ticker] = data['Close'][-1]

        min_ = []
        max_ = []
        median = []
        top_q = []
        bottom_q = []
        realized = []

        for window in windows:

            # get a dataframe with realized volatility
            estimator = realized_vol(window=window, price_data=data)
    #         print(estimator)

            # append the summary stats to a list
            min_.append(estimator.min())
            max_.append(estimator.max())
            median.append(estimator.median())
            top_q.append(estimator.quantile(quantiles[1]))
            bottom_q.append(estimator.quantile(quantiles[0]))
            realized.append(estimator[-1])
    #         print(min_)

        pct_list = []

        pct30 = (realized[0] - bottom_q[0]) / (top_q[0] - bottom_q[0]) * 100
        pct_list.append(pct30)
        pct60 = (realized[1] - bottom_q[1]) / (top_q[1] - bottom_q[1]) * 100
        pct_list.append(pct60)
        pct90 = (realized[2] - bottom_q[2]) / (top_q[2] - bottom_q[2]) * 100
        pct_list.append(pct90)
        pct120 = (realized[3] - bottom_q[3]) / (top_q[3] - bottom_q[3]) * 100
        pct_list.append(pct120)

    #     print(pct30)
    #     print(pct60)
    #     print(pct90)
    #     print(pct120)
    #     print(pct_list)

        avg_pct = sum(pct_list)/len(pct_list)
    #     print(avg_pct)

        completed_tkr_list.append(ticker)
        realized_vol_list.append(round(realized[1] * 100,2)) # this is realized vol for 60 day window
        avg_pct_list.append(round(avg_pct,2))
        pct30_list.append(round(pct30,2))
        pct60_list.append(round(pct60,2))
        pct90_list.append(round(pct90,2))
        pct120_list.append(round(pct120,2))

        counter += 1
        
    except Exception as e:
        print(f'{tkr} was not found.')
        print(f'Exception: {e}')
        print(f'Error:\n{sys.exc_info()}')
        counter += 1
# Out:
# Processing SPY, 1 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing QQQ, 2 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SPXU, 3 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AAPL, 4 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AMZN, 5 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TSLA, 6 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AMD, 7 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VIX, 8 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing IWM, 9 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HYG, 10 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing META, 11 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NVDA, 12 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AMC, 13 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing F, 14 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BABA, 15 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SOFI, 16 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UBER, 17 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TQQQ, 18 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing WBD, 19 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CHPT, 20 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PYPL, 21 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NKLA, 22 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing INTC, 23 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing COIN, 24 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EEM, 25 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MSFT, 26 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GOOGL, 27 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HOOD, 28 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing XLF, 29 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UVXY, 30 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SNAP, 31 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DIA, 32 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EWW, 33 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EWZ, 34 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FXI, 35 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GDX, 36 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GDXJ, 37 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GLD, 38 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SLV, 39 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SMH, 40 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TLT, 41 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing USO, 42 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VXX, 43 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing XLE, 44 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing XLU, 45 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing XOP, 46 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing IPOF, 47 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing IMPP, 48 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VYGG, 49 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EBON, 50 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BKLN, 51 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MEIP, 52 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CCL, 53 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing IDEX, 54 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BBD, 55 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TIGR, 56 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing T, 57 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PLTR, 58 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CBIO, 59 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AAL, 60 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ET, 61 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BAC, 62 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BNGO, 63 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ONEM, 64 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EWG, 65 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MNMD, 66 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ANY, 67 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BIOR, 68 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing RIG, 69 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PFE, 70 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MMAT, 71 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing C, 72 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MULN, 73 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CGC, 74 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AGNC, 75 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing KO, 76 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EVFM, 77 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TLRY, 78 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NLY, 79 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PLBY, 80 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NRZ, 81 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NIO, 82 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NYMT, 83 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GOTU, 84 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DS, 85 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CTLP, 86 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VRM, 87 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HGEN, 88 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AGEN, 89 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ACRX, 90 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NMTR, 91 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CRNT, 92 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing OEG, 93 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing THCA, 94 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CEI, 95 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing RIOT, 96 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing WFC, 97 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TRX, 98 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BBIG, 99 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NU, 100 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CRBP, 101 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NCLH, 102 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TEVA, 103 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CSCO, 104 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing KGC, 105 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PINS, 106 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BITF, 107 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FUBO, 108 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LAZR, 109 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ARCC, 110 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UAL, 111 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GOLD, 112 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VALE, 113 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FTCH, 114 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CRU, 115 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLSN, 116 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DNN, 117 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing KMI, 118 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NAK, 119 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NNDM, 120 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TSM, 121 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLVS, 122 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VZ, 123 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing STLA, 124 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DNA, 125 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SAN, 126 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PNNT, 127 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FENG, 128 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AGCB, 129 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing WISH, 130 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GM, 131 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ABEO, 132 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ASHR, 133 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PARA, 134 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HTZ, 135 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing JBLU, 136 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BCS, 137 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CONX, 138 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing XOM, 139 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AMRN, 140 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GOCO, 141 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CBAT, 142 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AM, 143 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MDVL, 144 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BITO, 145 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DKNG, 146 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ATY, 147 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UUP, 148 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SIRI, 149 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NOK, 150 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing KWEB, 151 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PTON, 152 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PIPP, 153 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TRVG, 154 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLOV, 155 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing OXY, 156 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MPW, 157 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ACB, 158 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NEM, 159 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AMRX, 160 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AXU, 161 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HUT, 162 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing RUN, 163 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GNUS, 164 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CORZ, 165 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TWTR, 166 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NLOK, 167 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DAL, 168 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GLBS, 169 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLF, 170 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ADVM, 171 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AEM, 172 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TEF, 173 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing IPOD, 174 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GFI, 175 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AQMS, 176 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing JPM, 177 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ITUB, 178 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EWC, 179 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UEC, 180 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UAMY, 181 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AKBA, 182 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DM, 183 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LDI, 184 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BEKE, 185 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CS, 186 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TBT, 187 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing OPEN, 188 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LUMN, 189 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EVOK, 190 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FSK, 191 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BODY, 192 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UNIT, 193 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SKLZ, 194 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BB, 195 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CIM, 196 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing M, 197 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CPG, 198 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BRFS, 199 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LFLY, 200 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SWN, 201 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LCID, 202 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FCX, 203 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BTI, 204 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing YSG, 205 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DIS, 206 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HL, 207 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MARA, 208 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AYRO, 209 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing EFA, 210 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MO, 211 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ATUS, 212 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing XSPA, 213 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing DRRX, 214 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SFT, 215 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GDRX, 216 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BEST, 217 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UXIN, 218 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing YVR, 219 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing SFL, 220 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BMY, 221 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GORO, 222 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BIRD, 223 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing NILE, 224 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GILT, 225 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CCJ, 226 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BP, 227 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ATAI, 228 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ALZN, 229 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FATH, 230 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing PLG, 231 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing FSM, 232 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing UDN, 233 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing ARKK, 234 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AUY, 235 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing RNWK, 236 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLNE, 237 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLVR, 238 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AGI, 239 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LYFT, 240 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing AVTR, 241 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MP, 242 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing VTNR, 243 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CLSK, 244 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing GOEV, 245 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing KERN, 246 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing LVS, 247 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing BOXD, 248 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing MRO, 249 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing TTOO, 250 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing STWD, 251 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing CVE, 252 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing RKT, 253 of 254...
# [*********************100%***********************]  1 of 1 completed
# Processing HMLP, 254 of 254...
# [*********************100%***********************]  1 of 1 completed

# %%
import pandas as pd

pct_dictionary = {
    'ticker':completed_tkr_list,
    'realized_vol':realized_vol_list,
    'avg_pct':avg_pct_list,
    'pct30':pct30_list,
    'pct60':pct60_list,
    'pct90':pct90_list,
    'pct120':pct120_list
}

cheap_df = pd.DataFrame(pct_dictionary)
cheap_df = cheap_df.sort_values(['avg_pct'])
cheap_df.to_csv('../0_data_dump/optionistics/realized_vol.csv')
print(f'Size of cheap_df is {len(cheap_df)}')
cheap_df
# Out:
# Size of cheap_df is 254
#     ticker  realized_vol  avg_pct   pct30   pct60   pct90  pct120
# 5     TSLA         43.26  -187.76  -59.29 -198.17 -257.70 -235.89
# 235   RNWK         13.57  -161.04 -194.85 -245.12  -89.40 -114.78
# 196      M         54.16  -139.69  -29.25  -46.03 -406.80  -76.68
# 46    IPOF          1.74  -129.37   -5.28  -50.64  -81.33 -380.24
# 29    UVXY         79.00  -127.47  -11.10  -35.20 -320.06 -143.51
# ..     ...           ...      ...     ...     ...     ...     ...
# 78     NLY         36.65   190.01  295.34  193.71  115.19  155.79
# 104    KGC         54.56   196.21  183.51  158.49  172.29  270.54
# 242   VTNR        162.78   252.58   13.03  313.51  345.93  337.84
# 65    MNMD        202.39   361.63  524.35  287.72  295.30  339.15
# 58    CBIO           NaN      NaN     NaN     NaN     NaN     NaN
#
# [254 rows x 7 columns]

# %%
import glob
import os

# Get the latest file from the directory
list_of_files = glob.glob('../0_inputs/asset_screeners/Finviz_Data/*') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)
# Out:
# ../0_inputs/asset_screeners/Finviz_Data\finviz (75).csv

# %%
import pandas as pd
import numpy as np

col_names = {
    'Ticker':'ticker',
    'Float Short':'float_short'
}

# Bring finviz.csv file into dataframe
finviz_df = pd.read_csv(latest_file)
finviz_df = finviz_df.rename(columns=col_names)
finviz_df = finviz_df[['ticker','float_short']]
finviz_df['float_short'] = finviz_df['float_short'].str.slice(0,-1) # remove the % character from the end of the string
finviz_df['float_short'] = finviz_df['float_short'].astype(str).astype(float) # convert to float for proper sorting
finviz_df = finviz_df.sort_values(['float_short'],ascending=False)

# Add Relative Volume Logic here
finviz_df['float_short_pt'] = 0
finviz_df['float_short_pt'] = np.select(condlist=[(finviz_df['float_short']>finviz_df['float_short'].quantile(0.85))],
                           choicelist=[1],
                           default=0)

# finviz_df = finviz_df[finviz_df['float_short'] > finviz_df['float_short'].quantile(.85)]
# finviz_df2 = finviz_df[finviz_df['float_short_pt']==1]
print(f'Size of finviz_df is {len(finviz_df)}.')
finviz_df.head(3)
# Out:
# Size of finviz_df is 8508.
#      ticker  float_short  float_short_pt
# 126    ADTX       130.15               1
# 6215   PXMD        59.89               1
# 437    APRN        52.78               1

# %%
# Optional for if internet is running slow
# cheap_df = pd.read_csv('../0_data_dump/optionistics/realized_vol_output.csv')
# cheap_df = cheap_df.drop('Unnamed: 0', axis=1)

# Add Relative Volume Logic here
cheap_df['cheap_pt'] = 0
cheap_df['cheap_pt'] = np.select(condlist=[(cheap_df['avg_pct'] < 0)],
                           choicelist=[1],
                           default=0)

print(f'Size of cheap_df is {len(cheap_df)}')
cheap_df.head(3)
# Out:
# Size of cheap_df is 254
#     ticker  realized_vol  avg_pct   pct30   pct60  pct90  pct120  cheap_pt
# 5     TSLA         43.26  -187.76  -59.29 -198.17 -257.7 -235.89         1
# 235   RNWK         13.57  -161.04 -194.85 -245.12  -89.4 -114.78         1
# 196      M         54.16  -139.69  -29.25  -46.03 -406.8  -76.68         1

# %% [markdown]
# Implied volatility premium or discount calculations here.

# %%
import yfinance as yf
import datetime
import sys

today_date = datetime.datetime.now()
target_date = today_date + datetime.timedelta(days=75) # calendar days

# ticker_list = ['AAPL','TSLA','MSFT'] # test list

ticker_list2 = []
expiry_list = []
strike_list = []
iv_list = []
counter = 1

for ticker in ticker_list:
    
    try:
        print(f'\nProcessing {ticker}, {counter} of {len(ticker_list)}...')
        
        # options_data = yf.Ticker("MSFT") # test input
        options_data = yf.Ticker(ticker)
        option_dates_list = options_data.options

        closest_date = today_date

        for x in option_dates_list:
            x = datetime.datetime.strptime(x, '%Y-%m-%d')
        #     print(x,',',(x-target_date).days)
            if (abs((x - target_date).days)) < abs(((closest_date - target_date).days)):
                closest_date = x

        # print(closest_date)
        # days_to_expiration = (closest_date - today_date).days
        # print(days_to_expiration)
        closest_date = closest_date.strftime("%Y-%m-%d")
#         print(f'Closest expiry is: {closest_date}')

        opt = options_data.option_chain(closest_date)
        strike_price_np_array = opt[0]['strike'].to_numpy()

        if ticker in cur_price_dict:
            cur_price = cur_price_dict[ticker]
        else:
            data = yf.download(
                tickers = tkr,
                period = "5d",
                interval = "1d",
                group_by = 'ticker',
                auto_adjust = True,
                prepost = True,
                threads = True,
                proxy = None
            )
            cur_price = data['Close'][-1]
        
#         cur_price = 280 # test input
        closest_strike = 0

        strike_ctr = 0
        
        for x in strike_price_np_array:
            if abs(cur_price - x) < abs(cur_price - closest_strike):
                closest_strike = x
                strike_index = strike_ctr
            strike_ctr += 1

#         print(f'Closest strike price is: {closest_strike}')

        strike_df = opt[0][opt[0]['strike']==closest_strike]
        implied_vol = round(strike_df['impliedVolatility'][strike_index] * 100,2)
#         print(f'Implied volatility is: {implied_vol}')

        ticker_list2.append(ticker)
        expiry_list.append(closest_date)
        strike_list.append(closest_strike)
        iv_list.append(implied_vol)
        counter += 1
    
    except Exception as e:
        print(f'{ticker}, {counter} not found.')
        print(f'Exception is {e}')
        print(f'Error is: {sys.exc_info()}')
        counter += 1
# Out:
# Processing SPY, 1 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 357.0
# Implied volatility is: 30.54
#
# Processing QQQ, 2 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 268.0
# Implied volatility is: 36.78
#
# Processing SPXU, 3 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 22.0
# Implied volatility is: 84.96
#
# Processing AAPL, 4 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 140.0
# Implied volatility is: 42.34
#
# Processing AMZN, 5 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 113.0
# Implied volatility is: 50.82
#
# Processing TSLA, 6 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 266.67
# Implied volatility is: 67.17
#
# Processing AMD, 7 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 65.0
# Implied volatility is: 60.47
#
# Processing VIX, 8 of 254...
# Closest expiry is: 2022-09-30
# VIX, 8 not found.
# Exception is Expiration `2022-09-30` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-30` cannot be found. Available expiration are: []'), <traceback object at 0x00000163693A0148>)
#
# Processing IWM, 9 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 165.0
# Implied volatility is: 34.5
#
# Processing HYG, 10 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 71.0
# Implied volatility is: 13.7
#
# Processing META, 11 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 135.0
# Implied volatility is: 56.64
#
# Processing NVDA, 12 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 120.0
# Implied volatility is: 63.61
#
# Processing AMC, 13 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 111.33
#
# Processing F, 14 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 11.0
# Implied volatility is: 53.81
#
# Processing BABA, 15 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 80.0
# Implied volatility is: 59.23
#
# Processing SOFI, 16 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 85.55
#
# Processing UBER, 17 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 27.5
# Implied volatility is: 66.06
#
# Processing TQQQ, 18 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 19.0
# Implied volatility is: 101.66
#
# Processing WBD, 19 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.5
# Implied volatility is: 65.53
#
# Processing CHPT, 20 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 15.0
# Implied volatility is: 86.13
#
# Processing PYPL, 21 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 85.0
# Implied volatility is: 59.55
#
# Processing NKLA, 22 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 4.0
# Implied volatility is: 100.0
#
# Processing INTC, 23 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 26.0
# Implied volatility is: 42.48
#
# Processing COIN, 24 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 65.0
# Implied volatility is: 110.35
#
# Processing EEM, 25 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 35.0
# Implied volatility is: 32.81
#
# Processing MSFT, 26 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 235.0
# Implied volatility is: 37.55
#
# Processing GOOGL, 27 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 96.0
# Implied volatility is: 42.35
#
# Processing HOOD, 28 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 83.69
#
# Processing XLF, 29 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 30.0
# Implied volatility is: 34.28
#
# Processing UVXY, 30 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 13.0
# Implied volatility is: 126.27
#
# Processing SNAP, 31 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 86.91
#
# Processing DIA, 32 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 285.0
# Implied volatility is: 27.9
#
# Processing EWW, 33 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 45.0
# Implied volatility is: 31.42
#
# Processing EWZ, 34 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 30.0
# Implied volatility is: 46.58
#
# Processing FXI, 35 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 26.0
# Implied volatility is: 38.77
#
# Processing GDX, 36 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 24.0
# Implied volatility is: 46.78
#
# Processing GDXJ, 37 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 29.0
# Implied volatility is: 55.52
#
# Processing GLD, 38 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 155.0
# Implied volatility is: 19.97
#
# Processing SLV, 39 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 17.5
# Implied volatility is: 33.4
#
# Processing SMH, 40 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 185.0
# Implied volatility is: 43.83
#
# Processing TLT, 41 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 102.0
# Implied volatility is: 25.48
#
# Processing USO, 42 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 65.0
# Implied volatility is: 53.41
#
# Processing VXX, 43 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 21.0
# Implied volatility is: 81.79
#
# Processing XLE, 44 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 72.0
# Implied volatility is: 49.67
#
# Processing XLU, 45 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 66.0
# Implied volatility is: 47.74
#
# Processing XOP, 46 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 125.0
# Implied volatility is: 55.61
#
# Processing IPOF, 47 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 2.74
#
# Processing IMPP, 48 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0.5
# Implied volatility is: 168.75
#
# Processing VYGG, 49 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 4.59
#
# Processing EBON, 50 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# EBON, 50 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A3F7748>)
#
# Processing BKLN, 51 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 20.0
# Implied volatility is: 25.59
#
# Processing MEIP, 52 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# MEIP, 52 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x0000016369273B88>)
#
# Processing CCL, 53 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.5
# Implied volatility is: 93.36
#
# Processing IDEX, 54 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0.5
# Implied volatility is: 225.0
#
# Processing BBD, 55 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 3.5
# Implied volatility is: 53.91
#
# Processing TIGR, 56 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 58.2
#
# Processing T, 57 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 15.0
# Implied volatility is: 27.74
#
# Processing PLTR, 58 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 74.71
#
# Processing CBIO, 59 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# CBIO, 59 not found.
# Exception is 5
# Error is: (<class 'KeyError'>, KeyError(5), <traceback object at 0x000001636A52ADC8>)
#
# Processing AAL, 60 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.0
# Implied volatility is: 68.36
#
# Processing ET, 61 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 11.0
# Implied volatility is: 45.12
#
# Processing BAC, 62 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 30.0
# Implied volatility is: 41.02
#
# Processing BNGO, 63 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.0
# Implied volatility is: 114.06
#
# Processing ONEM, 64 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.5
# Implied volatility is: 13.67
#
# Processing EWG, 65 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 20.0
# Implied volatility is: 37.01
#
# Processing MNMD, 66 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 0.0
#
# Processing ANY, 67 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0.5
# Implied volatility is: 215.63
#
# Processing BIOR, 68 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0.5
# Implied volatility is: 121.88
#
# Processing RIG, 69 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 89.45
#
# Processing PFE, 70 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 45.0
# Implied volatility is: 31.15
#
# Processing MMAT, 71 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0.5
# Implied volatility is: 215.63
#
# Processing C, 72 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 42.5
# Implied volatility is: 39.55
#
# Processing MULN, 73 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0.5
# Implied volatility is: 253.13
#
# Processing CGC, 74 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 101.56
#
# Processing AGNC, 75 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 48.63
#
# Processing KO, 76 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 55.0
# Implied volatility is: 27.64
#
# Processing EVFM, 77 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# EVFM, 77 not found.
# Exception is 7
# Error is: (<class 'KeyError'>, KeyError(7), <traceback object at 0x000001636926A408>)
#
# Processing TLRY, 78 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 95.31
#
# Processing NLY, 79 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 0.0
#
# Processing PLBY, 80 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 105.86
#
# Processing NRZ, 81 of 254...
# Closest expiry is: 2022-09-30
# NRZ, 81 not found.
# Exception is Expiration `2022-09-30` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-30` cannot be found. Available expiration are: []'), <traceback object at 0x00000163693AB6C8>)
#
# Processing NIO, 82 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 15.0
# Implied volatility is: 83.35
#
# Processing NYMT, 83 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 47.66
#
# Processing GOTU, 84 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 126.56
#
# Processing DS, 85 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# DS, 85 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000163693A0848>)
#
# Processing CTLP, 86 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 153.91
#
# Processing VRM, 87 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.5
# Implied volatility is: 165.63
#
# Processing HGEN, 88 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# HGEN, 88 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x000001636A4F0408>)
#
# Processing AGEN, 89 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.0
# Implied volatility is: 110.16
#
# Processing ACRX, 90 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# ACRX, 90 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x000001636A60FD88>)
#
# Processing NMTR, 91 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# NMTR, 91 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x000001636A60A188>)
#
# Processing CRNT, 92 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 65.63
#
# Processing OEG, 93 of 254...
# Closest expiry is: 2022-09-30
# OEG, 93 not found.
# Exception is Expiration `2022-09-30` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-30` cannot be found. Available expiration are: []'), <traceback object at 0x000001636925BF88>)
#
# Processing THCA, 94 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 68.56
#
# Processing CEI, 95 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# CEI, 95 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x000001636A608C08>)
#
# Processing RIOT, 96 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 115.82
#
# Processing WFC, 97 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 40.0
# Implied volatility is: 41.41
#
# Processing TRX, 98 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# TRX, 98 not found.
# Exception is 8
# Error is: (<class 'KeyError'>, KeyError(8), <traceback object at 0x0000016369273B88>)
#
# Processing BBIG, 99 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 164.06
#
# Processing NU, 100 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 4.5
# Implied volatility is: 83.2
#
# Processing CRBP, 101 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# CRBP, 101 not found.
# Exception is 8
# Error is: (<class 'KeyError'>, KeyError(8), <traceback object at 0x000001636A60A448>)
#
# Processing NCLH, 102 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.5
# Implied volatility is: 86.13
#
# Processing TEVA, 103 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 52.34
#
# Processing CSCO, 104 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 40.0
# Implied volatility is: 33.59
#
# Processing KGC, 105 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 4.0
# Implied volatility is: 62.89
#
# Processing PINS, 106 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 22.5
# Implied volatility is: 83.59
#
# Processing BITF, 107 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 134.38
#
# Processing FUBO, 108 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 3.5
# Implied volatility is: 119.14
#
# Processing LAZR, 109 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.5
# Implied volatility is: 99.02
#
# Processing ARCC, 110 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 17.0
# Implied volatility is: 34.13
#
# Processing UAL, 111 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 33.0
# Implied volatility is: 62.77
#
# Processing GOLD, 112 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 15.0
# Implied volatility is: 46.05
#
# Processing VALE, 113 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 13.0
# Implied volatility is: 50.88
#
# Processing FTCH, 114 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.0
# Implied volatility is: 109.77
#
# Processing CRU, 115 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 4.69
#
# Processing CLSN, 116 of 254...
# Closest expiry is: 2022-09-30
# CLSN, 116 not found.
# Exception is Expiration `2022-09-30` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-30` cannot be found. Available expiration are: []'), <traceback object at 0x00000163691FB3C8>)
#
# Processing DNN, 117 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 92.19
#
# Processing KMI, 118 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 17.0
# Implied volatility is: 30.47
#
# Processing NAK, 119 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# NAK, 119 not found.
# Exception is 7
# Error is: (<class 'KeyError'>, KeyError(7), <traceback object at 0x000001636A617D08>)
#
# Processing NNDM, 120 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 63.28
#
# Processing TSM, 121 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 70.0
# Implied volatility is: 42.52
#
# Processing CLVS, 122 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 209.38
#
# Processing VZ, 123 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 38.0
# Implied volatility is: 24.76
#
# Processing STLA, 124 of 254...
# Closest expiry is: 2022-12-16
# STLA, 124 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A5F5708>)
#
# Processing DNA, 125 of 254...
# DNA, 125 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A60AE88>)
#
# Processing SAN, 126 of 254...
# SAN, 126 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A5F5608>)
#
# Processing PNNT, 127 of 254...
# PNNT, 127 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A5713C8>)
#
# Processing FENG, 128 of 254...
# FENG, 128 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A6044C8>)
#
# Processing AGCB, 129 of 254...
# AGCB, 129 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A4F0DC8>)
#
# Processing WISH, 130 of 254...
# WISH, 130 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A608288>)
#
# Processing GM, 131 of 254...
# GM, 131 not found.
# Exception is ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Error is: (<class 'requests.exceptions.ConnectionError'>, ConnectionError(ProtocolError('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))), <traceback object at 0x000001636A60FE08>)
#
# Processing ABEO, 132 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 0.0
#
# Processing ASHR, 133 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 27.0
# Implied volatility is: 28.47
#
# Processing PARA, 134 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 20.0
# Implied volatility is: 56.74
#
# Processing HTZ, 135 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 17.5
# Implied volatility is: 61.72
#
# Processing JBLU, 136 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 68.16
#
# Processing BCS, 137 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 6.0
# Implied volatility is: 60.16
#
# Processing CONX, 138 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 3.61
#
# Processing XOM, 139 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 87.5
# Implied volatility is: 40.3
#
# Processing AMRN, 140 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 148.44
#
# Processing GOCO, 141 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# GOCO, 141 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A608A48>)
#
# Processing CBAT, 142 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# CBAT, 142 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636928D048>)
#
# Processing AM, 143 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 32.42
#
# Processing MDVL, 144 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# MDVL, 144 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x000001636A604508>)
#
# Processing BITO, 145 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.0
# Implied volatility is: 70.41
#
# Processing DKNG, 146 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 15.0
# Implied volatility is: 91.41
#
# Processing ATY, 147 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 156.25
#
# Processing UUP, 148 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 30.0
# Implied volatility is: 17.29
#
# Processing SIRI, 149 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 0.0
#
# Processing NOK, 150 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 4.5
# Implied volatility is: 42.77
#
# Processing KWEB, 151 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 25.0
# Implied volatility is: 56.69
#
# Processing PTON, 152 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 122.27
#
# Processing PIPP, 153 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 10.0
# Implied volatility is: 7.23
#
# Processing TRVG, 154 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# TRVG, 154 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x0000016369273B88>)
#
# Processing CLOV, 155 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.5
# Implied volatility is: 103.91
#
# Processing OXY, 156 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 62.5
# Implied volatility is: 57.73
#
# Processing MPW, 157 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.0
# Implied volatility is: 70.9
#
# Processing ACB, 158 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 114.06
#
# Processing NEM, 159 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 42.5
# Implied volatility is: 44.36
#
# Processing AMRX, 160 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 96.48
#
# Processing AXU, 161 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# AXU, 161 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000163693AC908>)
#
# Processing HUT, 162 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.0
# Implied volatility is: 148.05
#
# Processing RUN, 163 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 27.5
# Implied volatility is: 89.89
#
# Processing GNUS, 164 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0.5
# Implied volatility is: 175.0
#
# Processing CORZ, 165 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.5
# Implied volatility is: 125.0
#
# Processing TWTR, 166 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 44.0
# Implied volatility is: 70.56
#
# Processing NLOK, 167 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 20.0
# Implied volatility is: 144.82
#
# Processing DAL, 168 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 28.0
# Implied volatility is: 55.23
#
# Processing GLBS, 169 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 126.56
#
# Processing CLF, 170 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 13.0
# Implied volatility is: 71.68
#
# Processing ADVM, 171 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# ADVM, 171 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x000001636A604148>)
#
# Processing AEM, 172 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 40.0
# Implied volatility is: 50.98
#
# Processing TEF, 173 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 95.31
#
# Processing IPOD, 174 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 3.13
#
# Processing GFI, 175 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 8.0
# Implied volatility is: 59.96
#
# Processing AQMS, 176 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# AQMS, 176 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x000001636A3F7E88>)
#
# Processing JPM, 177 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 105.0
# Implied volatility is: 36.49
#
# Processing ITUB, 178 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 50.59
#
# Processing EWC, 179 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 30.0
# Implied volatility is: 31.35
#
# Processing UEC, 180 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 93.36
#
# Processing UAMY, 181 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# UAMY, 181 not found.
# Exception is 6
# Error is: (<class 'KeyError'>, KeyError(6), <traceback object at 0x000001636A5D9AC8>)
#
# Processing AKBA, 182 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0.5
# Implied volatility is: 175.0
#
# Processing DM, 183 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 98.05
#
# Processing LDI, 184 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 95.31
#
# Processing BEKE, 185 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 17.5
# Implied volatility is: 72.66
#
# Processing CS, 186 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 4.0
# Implied volatility is: 60.55
#
# Processing TBT, 187 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 32.0
# Implied volatility is: 50.29
#
# Processing OPEN, 188 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.0
# Implied volatility is: 111.33
#
# Processing LUMN, 189 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.0
# Implied volatility is: 64.84
#
# Processing EVOK, 190 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# EVOK, 190 not found.
# Exception is index 4 is out of bounds for axis 0 with size 0
# Error is: (<class 'IndexError'>, IndexError('index 4 is out of bounds for axis 0 with size 0'), <traceback object at 0x00000163693AB888>)
#
# Processing FSK, 191 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.5
# Implied volatility is: 43.85
#
# Processing BODY, 192 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# BODY, 192 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A52AE48>)
#
# Processing UNIT, 193 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 8.0
# Implied volatility is: 56.25
#
# Processing SKLZ, 194 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 129.69
#
# Processing BB, 195 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 70.51
#
# Processing CIM, 196 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 6.0
# Implied volatility is: 59.77
#
# Processing M, 197 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 16.0
# Implied volatility is: 69.29
#
# Processing CPG, 198 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 78.13
#
# Processing BRFS, 199 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 61.72
#
# Processing LFLY, 200 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 189.06
#
# Processing SWN, 201 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 6.0
# Implied volatility is: 69.92
#
# Processing LCID, 202 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 14.0
# Implied volatility is: 78.03
#
# Processing FCX, 203 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 27.0
# Implied volatility is: 61.62
#
# Processing BTI, 204 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 35.0
# Implied volatility is: 30.84
#
# Processing YSG, 205 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# YSG, 205 not found.
# Exception is 4
# Error is: (<class 'KeyError'>, KeyError(4), <traceback object at 0x000001636A571EC8>)
#
# Processing DIS, 206 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 95.0
# Implied volatility is: 44.06
#
# Processing HL, 207 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 4.0
# Implied volatility is: 73.83
#
# Processing MARA, 208 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 125.78
#
# Processing AYRO, 209 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# AYRO, 209 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x0000016368C643C8>)
#
# Processing EFA, 210 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 56.0
# Implied volatility is: 34.08
#
# Processing MO, 211 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 40.0
# Implied volatility is: 32.13
#
# Processing ATUS, 212 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 594.14
#
# Processing XSPA, 213 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 106.25
#
# Processing DRRX, 214 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# DRRX, 214 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A372248>)
#
# Processing SFT, 215 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# SFT, 215 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A60AB48>)
#
# Processing GDRX, 216 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 92.58
#
# Processing BEST, 217 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# BEST, 217 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x000001636938C988>)
#
# Processing UXIN, 218 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 196.88
#
# Processing YVR, 219 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# YVR, 219 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A5718C8>)
#
# Processing SFL, 220 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 50.78
#
# Processing BMY, 221 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 70.0
# Implied volatility is: 27.31
#
# Processing GORO, 222 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 92.97
#
# Processing BIRD, 223 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 90.63
#
# Processing NILE, 224 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# NILE, 224 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A60AF48>)
#
# Processing GILT, 225 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 52.15
#
# Processing CCJ, 226 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 27.0
# Implied volatility is: 64.26
#
# Processing BP, 227 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 29.0
# Implied volatility is: 39.65
#
# Processing ATAI, 228 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 357.81
#
# Processing ALZN, 229 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# ALZN, 229 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x000001636A52AE08>)
#
# Processing FATH, 230 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 142.97
#
# Processing PLG, 231 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 132.81
#
# Processing FSM, 232 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 74.22
#
# Processing UDN, 233 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 17.0
# Implied volatility is: 18.99
#
# Processing ARKK, 234 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 38.0
# Implied volatility is: 64.5
#
# Processing AUY, 235 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 4.5
# Implied volatility is: 53.91
#
# Processing RNWK, 236 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# RNWK, 236 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x000001636A5D5A88>)
#
# Processing CLNE, 237 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 83.79
#
# Processing CLVR, 238 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# CLVR, 238 not found.
# Exception is 4
# Error is: (<class 'KeyError'>, KeyError(4), <traceback object at 0x000001636A604108>)
#
# Processing AGI, 239 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.5
# Implied volatility is: 52.73
#
# Processing LYFT, 240 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 12.5
# Implied volatility is: 92.09
#
# Processing AVTR, 241 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 22.5
# Implied volatility is: 45.51
#
# Processing MP, 242 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 25.0
# Implied volatility is: 75.2
#
# Processing VTNR, 243 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 111.52
#
# Processing CLSK, 244 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 144.53
#
# Processing GOEV, 245 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.0
# Implied volatility is: 117.19
#
# Processing KERN, 246 of 254...
# Closest expiry is: 2023-01-20
# Closest strike price is: 0
# KERN, 246 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x000001636A372248>)
#
# Processing LVS, 247 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 38.0
# Implied volatility is: 58.86
#
# Processing BOXD, 248 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 153.13
#
# Processing MRO, 249 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 23.0
# Implied volatility is: 63.28
#
# Processing TTOO, 250 of 254...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# TTOO, 250 not found.
# Exception is 5
# Error is: (<class 'KeyError'>, KeyError(5), <traceback object at 0x000001636A604D48>)
#
# Processing STWD, 251 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 19.0
# Implied volatility is: 41.31
#
# Processing CVE, 252 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 15.0
# Implied volatility is: 65.23
#
# Processing RKT, 253 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 6.0
# Implied volatility is: 71.19
#
# Processing HMLP, 254 of 254...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 12.5

# %%
print('Completed.')
# Out:
# Completed.

# %% [markdown]
# Create a dataframe for the implied volatility data.

# %%
iv_dictionary = {
    'ticker':ticker_list2,
    'expiry':expiry_list,
    'strike':strike_list,
    'implied_vol':iv_list
}

iv_df = pd.DataFrame(iv_dictionary)
iv_df["implied_vol"] = iv_df["implied_vol"].astype(str).astype(float)
iv_df = iv_df.sort_values(['implied_vol'],ascending=False)
iv_df.to_csv('../0_data_dump/optionistics/implied_vols.csv')
print(f'Size of iv_df is {len(iv_df)}.')
iv_df.head(3)
# Out:
# Size of iv_df is 208.
#     ticker      expiry  strike  implied_vol
# 175   ATUS  2022-12-16     5.0       594.14
# 186   ATAI  2022-11-18     2.5       357.81
# 68    MULN  2022-11-18     0.5       253.13

# %%
print('Completed.')
# Out:
# Completed.

# %%
# for col in final_df.columns:
#     print(col)

# %%
final_df = pd.merge(cheap_df,finviz_df,on='ticker',how='left')
print(len(final_df))
# final_df = pd.merge(final_df,optionistics_data,on='ticker',how='outer')
# print(len(final_df))
final_df = pd.merge(final_df,iv_df,on='ticker',how='outer')
print(len(final_df))

final_df['iv_premium'] = final_df['implied_vol'] - final_df['realized_vol']

final_df['iv_prem_pt'] = 0
final_df['iv_prem_pt'] = np.select(condlist=[(final_df['iv_premium']>final_df['iv_premium'].quantile(0.85))],
                           choicelist=[1],
                           default=0)

# final_df['oi_pct_chg_pts'] = final_df['oi_pct_chg_pts'].fillna(0)
final_df['cheap_pt'] = final_df['cheap_pt'].fillna(0)
final_df['total_pts'] = final_df['cheap_pt'] + final_df['float_short_pt'] + final_df['iv_prem_pt']
final_df = final_df[['ticker','expiry','strike','total_pts','iv_prem_pt','cheap_pt','float_short_pt','iv_premium','avg_pct','float_short']]
final_df = final_df.sort_values(by = ['total_pts','float_short'],ascending=[False,False])
final_df = final_df[final_df['total_pts'] > 0]
final_df.to_csv('../0_data_dump/asset_screener/options_output.csv')
final_df.head(20)
# Out:
# 254
# 254
#     ticker      expiry  strike  total_pts  iv_prem_pt  cheap_pt  \
# 64    SKLZ  2022-11-18     1.0        3.0           1         1
# 76    CLSK  2022-12-16     2.5        3.0           1         1
# 79    MULN  2022-11-18     0.5        3.0           1         1
# 22    GNUS  2022-11-18     0.5        3.0           1         1
# 87    MMAT  2022-11-18     0.5        3.0           1         1
# 52    BITF  2022-12-16     1.0        3.0           1         1
# 50    IDEX  2022-11-18     0.5        3.0           1         1
# 28    SIRI  2022-12-16     5.0        2.0           0         1
# 17    NKLA  2022-11-18     4.0        2.0           0         1
# 175   CLVS  2022-11-18     1.0        2.0           1         0
# 82      DM  2022-12-16     2.5        2.0           0         1
# 208   ATUS  2022-12-16     5.0        2.0           1         0
# 86    RIOT  2022-12-16     7.0        2.0           0         1
# 49    GDRX  2022-11-18     5.0        2.0           0         1
# 41     UEC  2022-11-18     3.5        2.0           0         1
# 71    BIRD  2022-12-16     2.5        2.0           0         1
# 67    PLBY  2022-12-16     5.0        2.0           0         1
# 81     RUN  2022-12-16    27.5        2.0           0         1
# 77     AAL  2022-12-16    12.0        2.0           0         1
# 84    PARA  2022-12-16    20.0        2.0           0         1
#
#      float_short_pt  iv_premium  avg_pct  float_short
# 64              1.0       35.92   -20.67        17.94
# 76              1.0       42.86   -12.32        14.97
# 79              1.0      160.88    -9.50        13.78
# 22              1.0      106.30   -57.54        11.85
# 87              1.0      139.13    -3.84        11.04
# 52              1.0       36.70   -27.30         8.94
# 50              1.0      151.69   -29.44         8.66
# 28              1.0      -20.45   -49.26        33.38
# 17              1.0       21.07   -62.11        30.50
# 175             1.0       90.67    59.52        23.29
# 82              1.0       17.47    -6.07        22.57
# 208             1.0      508.92    96.81        19.51
# 86              1.0       24.83    -3.85        16.17
# 49              1.0       24.16   -30.29        15.27
# 41              1.0       12.98   -41.85        13.76
# 71              1.0        6.11   -16.70        13.55
# 67              1.0       25.54   -19.50        13.49
# 81              1.0       18.44    -7.41        13.10
# 77              1.0       21.87    -9.92        12.48
# 84              1.0       11.33    -4.55        11.21

# %%
toc = time.perf_counter()
total_time = toc - tic

print(f'Program completed in {total_time:.2f} seconds or {total_time/60:.2f} minutes on {datetime.datetime.now()}.')
# Out:
# Program completed in 404.39 seconds or 6.74 minutes on 2022-09-30 20:48:35.738433.
