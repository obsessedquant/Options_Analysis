# %% [markdown]
# # Options Screener
#
# This notebook is meant to analyze a list of tickers and output which tickers have the highest value call options with the highest probability of increasing in value in the short-term.
#
# Manual steps procedure:
# - Update options_list2.csv with the latest OI pct changes from Optionistics.com using the options_list_compare.xlsx file
# - Get the latest finviz file from the local directory
#
# This screener looks at the following attributes:
# - Whether an option is 'cheap' i.e. has low realized volatility compared to its historical realized volatility, the lowest 15% are given a point
# - Implied volatility premium or discount, the top 15% are given a point
# - Open interest % change from optionistics, these are given a point
# - Highest float short percent, the top 15% are given a point

# %% [markdown]
# ### REMEMBER TO UPDATE THE OPTIONS_LIST2.CSV MANUALLY, BE SURE TO LOG IN FIRST.

# %%
# %matplotlib inline

import math
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
import time

tic = time.perf_counter()

# %%
import pandas as pd

tickers_df = pd.read_csv('../0_inputs/asset_screeners/options_list1.csv')
optionistics_data = pd.read_csv('../0_inputs/asset_screeners/options_list2.csv')
# optionistics_data.head(3)

ticker_dictionary = {
    'VIX':'^VIX'
}

ticker_list_df = pd.merge(tickers_df[['ticker']],optionistics_data[['ticker']],on='ticker',how='outer')

ticker_list = ticker_list_df['ticker'].to_list()

# %%
def realized_vol(price_data, window=30):

#     print(price_data.tail(5))
    log_return = (price_data["Close"] / price_data["Close"].shift(1)).apply(np.log)

    return log_return.rolling(window=window, center=False).std() * math.sqrt(252)

# %%
# windows = [30, 60, 90, 120] # calendar days
windows = [22, 44, 66, 88] # trading days
quantiles = [0.25, 0.75]

min_ = []
max_ = []
median = []
top_q = []
bottom_q = []
realized = []

# %%
completed_tkr_list = []
realized_vol_list = []
avg_pct_list = []
pct30_list = []
pct60_list = []
pct90_list = []
pct120_list = []
counter = 1

cur_price_dict = {}

# ticker_list = ['AAPL','TSLA','MSFT'] # test list

for ticker in ticker_list:

    print(f"Processing {ticker}, {counter} of {len(ticker_list)}...")
    
    try:
        # data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")

        # start="2020-01-01", end="2020-12-31"

        # start_date = '2020-01-01'
        # end_date = '2020-12-31'

        if ticker in ticker_dictionary:
            tkr = ticker_dictionary[ticker]
        else: tkr = ticker

        data = yf.download(  # or pdr.get_data_yahoo(...
                # tickers list or string as well
                tickers = tkr,

                # use "period" instead of start/end
                # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
                # (optional, default is '1mo')
                period = "1y",

        #         start = start_date,
        #         end = end_date,

                # fetch data by interval (including intraday if period < 60 days)
                # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
                # (optional, default is '1d')
                interval = "1d",

                # group by ticker (to access via data['SPY'])
                # (optional, default is 'column')
                group_by = 'ticker',

                # adjust all OHLC automatically
                # (optional, default is False)
                auto_adjust = True,

                # download pre/post regular market hours data
                # (optional, default is False)
                prepost = True,

                # use threads for mass downloading? (True/False/Integer)
                # (optional, default is True)
                threads = True,

                # proxy URL scheme use use when downloading?
                # (optional, default is None)
                proxy = None
            )

        # data.to_csv('BTC_1hr_prices.csv')
        # data.head(3)
    #     print(data.tail(5))

        cur_price_dict[ticker] = data['Close'][-1]

        min_ = []
        max_ = []
        median = []
        top_q = []
        bottom_q = []
        realized = []

        for window in windows:

            # get a dataframe with realized volatility
            estimator = realized_vol(window=window, price_data=data)
    #         print(estimator)

            # append the summary stats to a list
            min_.append(estimator.min())
            max_.append(estimator.max())
            median.append(estimator.median())
            top_q.append(estimator.quantile(quantiles[1]))
            bottom_q.append(estimator.quantile(quantiles[0]))
            realized.append(estimator[-1])
    #         print(min_)

        pct_list = []

        pct30 = (realized[0] - bottom_q[0]) / (top_q[0] - bottom_q[0]) * 100
        pct_list.append(pct30)
        pct60 = (realized[1] - bottom_q[1]) / (top_q[1] - bottom_q[1]) * 100
        pct_list.append(pct60)
        pct90 = (realized[2] - bottom_q[2]) / (top_q[2] - bottom_q[2]) * 100
        pct_list.append(pct90)
        pct120 = (realized[3] - bottom_q[3]) / (top_q[3] - bottom_q[3]) * 100
        pct_list.append(pct120)

    #     print(pct30)
    #     print(pct60)
    #     print(pct90)
    #     print(pct120)
    #     print(pct_list)

        avg_pct = sum(pct_list)/len(pct_list)
    #     print(avg_pct)

        completed_tkr_list.append(ticker)
        realized_vol_list.append(round(realized[1] * 100,2)) # this is realized vol for 60 day window
        avg_pct_list.append(round(avg_pct,2))
        pct30_list.append(round(pct30,2))
        pct60_list.append(round(pct60,2))
        pct90_list.append(round(pct90,2))
        pct120_list.append(round(pct120,2))

        counter += 1
        
    except Exception as e:
        print(f'{tkr} was not found.')
        print(f'Exception: {e}')
        print(f'Error:\n{sys.exc_info()}')
        counter += 1
# Out:
# Processing SPY, 1 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing QQQ, 2 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SPXU, 3 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AAPL, 4 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AMZN, 5 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TSLA, 6 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AMD, 7 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VIX, 8 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing IWM, 9 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HYG, 10 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing META, 11 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NVDA, 12 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AMC, 13 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing F, 14 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BABA, 15 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SOFI, 16 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UBER, 17 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TQQQ, 18 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing WBD, 19 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CHPT, 20 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PYPL, 21 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NKLA, 22 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing INTC, 23 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing COIN, 24 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EEM, 25 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MSFT, 26 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GOOGL, 27 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HOOD, 28 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing XLF, 29 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UVXY, 30 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SNAP, 31 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DIA, 32 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EWW, 33 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EWZ, 34 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FXI, 35 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GDX, 36 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GDXJ, 37 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GLD, 38 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SLV, 39 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SMH, 40 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TLT, 41 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing USO, 42 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VXX, 43 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing XLE, 44 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing XLU, 45 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing XOP, 46 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing IPOF, 47 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing IMPP, 48 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VYGG, 49 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EBON, 50 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BKLN, 51 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MEIP, 52 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CCL, 53 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing IDEX, 54 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BBD, 55 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TIGR, 56 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing T, 57 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PLTR, 58 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CBIO, 59 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AAL, 60 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ET, 61 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BAC, 62 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BNGO, 63 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ONEM, 64 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EWG, 65 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MNMD, 66 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ANY, 67 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BIOR, 68 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RIG, 69 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PFE, 70 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MMAT, 71 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing C, 72 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MULN, 73 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CGC, 74 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AGNC, 75 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KO, 76 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EVFM, 77 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TLRY, 78 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NLY, 79 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PLBY, 80 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NRZ, 81 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NIO, 82 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NYMT, 83 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GOTU, 84 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DS, 85 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CTLP, 86 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VRM, 87 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HGEN, 88 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AGEN, 89 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ACRX, 90 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NMTR, 91 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CRNT, 92 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing OEG, 93 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing THCA, 94 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CEI, 95 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RIOT, 96 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing WFC, 97 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TRX, 98 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BBIG, 99 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NU, 100 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CRBP, 101 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NCLH, 102 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TEVA, 103 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CSCO, 104 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KGC, 105 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PINS, 106 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BITF, 107 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FUBO, 108 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LAZR, 109 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ARCC, 110 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UAL, 111 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GOLD, 112 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VALE, 113 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FTCH, 114 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CRU, 115 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLSN, 116 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DNN, 117 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KMI, 118 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NAK, 119 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NNDM, 120 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TSM, 121 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLVS, 122 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VZ, 123 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing STLA, 124 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DNA, 125 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SAN, 126 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PNNT, 127 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FENG, 128 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AGCB, 129 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing WISH, 130 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GM, 131 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ABEO, 132 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ASHR, 133 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PARA, 134 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HTZ, 135 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing JBLU, 136 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BCS, 137 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CONX, 138 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing XOM, 139 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AMRN, 140 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GOCO, 141 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CBAT, 142 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AM, 143 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MDVL, 144 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BITO, 145 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DKNG, 146 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ATY, 147 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UUP, 148 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SIRI, 149 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NOK, 150 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KWEB, 151 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PTON, 152 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PIPP, 153 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TRVG, 154 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLOV, 155 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing OXY, 156 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MPW, 157 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ACB, 158 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NEM, 159 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AMRX, 160 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AXU, 161 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HUT, 162 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RUN, 163 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GNUS, 164 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CORZ, 165 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TWTR, 166 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NLOK, 167 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DAL, 168 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GLBS, 169 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLF, 170 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ADVM, 171 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AEM, 172 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TEF, 173 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing IPOD, 174 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GFI, 175 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AQMS, 176 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing JPM, 177 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ITUB, 178 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EWC, 179 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UEC, 180 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UAMY, 181 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AKBA, 182 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DM, 183 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LDI, 184 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BEKE, 185 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CS, 186 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TBT, 187 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing OPEN, 188 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LUMN, 189 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EVOK, 190 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FSK, 191 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BODY, 192 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UNIT, 193 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SKLZ, 194 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BB, 195 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CIM, 196 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing M, 197 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CPG, 198 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BRFS, 199 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LFLY, 200 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SWN, 201 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LCID, 202 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FCX, 203 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BTI, 204 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing YSG, 205 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DIS, 206 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HL, 207 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MARA, 208 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AYRO, 209 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing EFA, 210 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MO, 211 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ATUS, 212 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing XSPA, 213 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DRRX, 214 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SFT, 215 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GDRX, 216 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BEST, 217 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UXIN, 218 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing YVR, 219 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SFL, 220 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BMY, 221 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GORO, 222 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BIRD, 223 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing NILE, 224 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GILT, 225 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CCJ, 226 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BP, 227 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ATAI, 228 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ALZN, 229 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FATH, 230 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PLG, 231 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FSM, 232 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UDN, 233 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ARKK, 234 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AUY, 235 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RNWK, 236 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLNE, 237 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLVR, 238 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AGI, 239 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LYFT, 240 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AVTR, 241 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MP, 242 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VTNR, 243 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLSK, 244 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GOEV, 245 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KERN, 246 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LVS, 247 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BOXD, 248 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MRO, 249 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TTOO, 250 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing STWD, 251 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CVE, 252 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RKT, 253 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HMLP, 254 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KOS, 255 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RVNC, 256 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CLR, 257 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PLAY, 258 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ALT, 259 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BOIL, 260 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PTEN, 261 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ASAN, 262 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TAN, 263 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SHEL, 264 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ENPH, 265 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MMM, 266 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SPWR, 267 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ASO, 268 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing STEM, 269 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BLNK, 270 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ULTA, 271 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing LULU, 272 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing CHRW, 273 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GSAT, 274 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FAZE, 275 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HD, 276 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing TRQ, 277 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GLW, 278 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VUZI, 279 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing FLEX, 280 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing VSTO, 281 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BAX, 282 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing GME, 283 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing AEO, 284 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing PEP, 285 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SEDG, 286 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing BHC, 287 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing UCO, 288 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing HST, 289 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ARRY, 290 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing RH, 291 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SO, 292 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing SPXS, 293 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing KHC, 294 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing DG, 295 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing MTCH, 296 of 297...
# [*********************100%***********************]  1 of 1 completed
# Processing ADM, 297 of 297...
# [*********************100%***********************]  1 of 1 completed

# %%
import pandas as pd

pct_dictionary = {
    'ticker':completed_tkr_list,
    'realized_vol':realized_vol_list,
    'avg_pct':avg_pct_list,
    'pct30':pct30_list,
    'pct60':pct60_list,
    'pct90':pct90_list,
    'pct120':pct120_list
}

cheap_df = pd.DataFrame(pct_dictionary)
cheap_df = cheap_df.sort_values(['avg_pct'])
cheap_df.to_csv('../0_data_dump/optionistics/realized_vol.csv')
print(f'Size of cheap_df is {len(cheap_df)}')
cheap_df
# Out:
# Size of cheap_df is 297
#     ticker  realized_vol  avg_pct   pct30    pct60   pct90  pct120
# 256    CLR         27.14  -156.23 -112.04  -351.33 -104.61  -56.93
# 29    UVXY         72.35  -134.56    2.02   -71.14 -378.54  -90.59
# 46    IPOF          1.90  -134.38  -63.46   -81.08 -184.39 -208.61
# 5     TSLA         48.25  -113.94 -112.26  -147.11 -172.31  -24.07
# 54     BBD         30.17  -104.87  -47.58   -56.63  -93.80 -221.48
# ..     ...           ...      ...     ...      ...     ...     ...
# 161    HUT        121.51   299.41  173.44   249.56  340.11  434.54
# 102   TEVA         74.93   374.08   25.12   558.75  510.50  401.94
# 242   VTNR        164.93   375.89  486.40   365.78  289.28  362.09
# 274   FAZE        203.54   518.92  450.58   533.69  535.14  556.26
# 87    HGEN        390.21   596.47   29.52  1118.86  953.94  283.56
#
# [297 rows x 7 columns]

# %%
import glob
import os

# Get the latest file from the directory
list_of_files = glob.glob('../0_inputs/asset_screeners/Finviz_Data/*') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)
# Out:
# ../0_inputs/asset_screeners/Finviz_Data\finviz (64).csv

# %%
import pandas as pd
import numpy as np

col_names = {
    'Ticker':'ticker',
    'Float Short':'float_short'
}

# Bring finviz.csv file into dataframe
finviz_df = pd.read_csv(latest_file)
finviz_df = finviz_df.rename(columns=col_names)
finviz_df = finviz_df[['ticker','float_short']]
finviz_df['float_short'] = finviz_df['float_short'].str.slice(0,-1) # remove the % character from the end of the string
finviz_df['float_short'] = finviz_df['float_short'].astype(str).astype(float) # convert to float for proper sorting
finviz_df = finviz_df.sort_values(['float_short'],ascending=False)

# Add Relative Volume Logic here
finviz_df['float_short_pt'] = 0
finviz_df['float_short_pt'] = np.select(condlist=[(finviz_df['float_short']>finviz_df['float_short'].quantile(0.85))],
                           choicelist=[1],
                           default=0)

# finviz_df = finviz_df[finviz_df['float_short'] > finviz_df['float_short'].quantile(.85)]
# finviz_df2 = finviz_df[finviz_df['float_short_pt']==1]
print(f'Size of finviz_df is {len(finviz_df)}.')
finviz_df.head(3)
# Out:
# Size of finviz_df is 8531.
#      ticker  float_short  float_short_pt
# 2530   ESTE        51.14               1
# 3822   ICPT        46.84               1
# 2684   FAZE        39.95               1

# %%
# Optional for if internet is running slow
# cheap_df = pd.read_csv('../0_data_dump/optionistics/realized_vol_output.csv')
# cheap_df = cheap_df.drop('Unnamed: 0', axis=1)

# Add Relative Volume Logic here
cheap_df['cheap_pt'] = 0
cheap_df['cheap_pt'] = np.select(condlist=[(cheap_df['avg_pct'] < 0)],
                           choicelist=[1],
                           default=0)

print(f'Size of cheap_df is {len(cheap_df)}')
cheap_df.head(3)
# Out:
# Size of cheap_df is 297
#     ticker  realized_vol  avg_pct   pct30   pct60   pct90  pct120  cheap_pt
# 256    CLR         27.14  -156.23 -112.04 -351.33 -104.61  -56.93         1
# 29    UVXY         72.35  -134.56    2.02  -71.14 -378.54  -90.59         1
# 46    IPOF          1.90  -134.38  -63.46  -81.08 -184.39 -208.61         1

# %% [markdown]
# Implied volatility premium or discount calculations here.

# %%
import yfinance as yf
import datetime
import sys

today_date = datetime.datetime.now()
target_date = today_date + datetime.timedelta(days=75) # calendar days

# ticker_list = ['AAPL','TSLA','MSFT'] # test list

ticker_list2 = []
expiry_list = []
strike_list = []
iv_list = []
counter = 1

for ticker in ticker_list:
    
    try:
        print(f'\nProcessing {ticker}, {counter} of {len(ticker_list)}...')
        
        # options_data = yf.Ticker("MSFT") # test input
        options_data = yf.Ticker(ticker)
        option_dates_list = options_data.options

        closest_date = today_date

        for x in option_dates_list:
            x = datetime.datetime.strptime(x, '%Y-%m-%d')
        #     print(x,',',(x-target_date).days)
            if (abs((x - target_date).days)) < abs(((closest_date - target_date).days)):
                closest_date = x

        # print(closest_date)
        # days_to_expiration = (closest_date - today_date).days
        # print(days_to_expiration)
        closest_date = closest_date.strftime("%Y-%m-%d")
        print(f'Closest expiry is: {closest_date}')

        opt = options_data.option_chain(closest_date)
        strike_price_np_array = opt[0]['strike'].to_numpy()

        if ticker in cur_price_dict:
            cur_price = cur_price_dict[ticker]
        else:
            data = yf.download(
                tickers = tkr,
                period = "5d",
                interval = "1d",
                group_by = 'ticker',
                auto_adjust = True,
                prepost = True,
                threads = True,
                proxy = None
            )
            cur_price = data['Close'][-1]
        
#         cur_price = 280 # test input
        closest_strike = 0

        strike_ctr = 0
        
        for x in strike_price_np_array:
            if abs(cur_price - x) < abs(cur_price - closest_strike):
                closest_strike = x
                strike_index = strike_ctr
            strike_ctr += 1

        print(f'Closest strike price is: {closest_strike}')

        strike_df = opt[0][opt[0]['strike']==closest_strike]
        implied_vol = round(strike_df['impliedVolatility'][strike_index] * 100,2)
        print(f'Implied volatility is: {implied_vol}')

        ticker_list2.append(ticker)
        expiry_list.append(closest_date)
        strike_list.append(closest_strike)
        iv_list.append(implied_vol)
        counter += 1
    
    except Exception as e:
        print(f'{ticker}, {counter} not found.')
        print(f'Exception is {e}')
        print(f'Error is: {sys.exc_info()}')
        counter += 1
# Out:
# Processing SPY, 1 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 400.0
# Implied volatility is: 23.12
#
# Processing QQQ, 2 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 301.0
# Implied volatility is: 30.34
#
# Processing SPXU, 3 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 16.0
# Implied volatility is: 69.09
#
# Processing AAPL, 4 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 155.0
# Implied volatility is: 32.96
#
# Processing AMZN, 5 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 130.0
# Implied volatility is: 43.98
#
# Processing TSLA, 6 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 286.67
# Implied volatility is: 58.05
#
# Processing AMD, 7 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 85.0
# Implied volatility is: 53.37
#
# Processing VIX, 8 of 297...
# Closest expiry is: 2022-09-08
# VIX, 8 not found.
# Exception is Expiration `2022-09-08` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-08` cannot be found. Available expiration are: []'), <traceback object at 0x00000185C615EA88>)
#
# Processing IWM, 9 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 184.0
# Implied volatility is: 26.89
#
# Processing HYG, 10 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 76.0
# Implied volatility is: 11.95
#
# Processing META, 11 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 160.0
# Implied volatility is: 53.49
#
# Processing NVDA, 12 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 140.0
# Implied volatility is: 56.69
#
# Processing AMC, 13 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 9.0
# Implied volatility is: 119.53
#
# Processing F, 14 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 15.0
# Implied volatility is: 46.39
#
# Processing BABA, 15 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 90.0
# Implied volatility is: 54.82
#
# Processing SOFI, 16 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 6.0
# Implied volatility is: 79.88
#
# Processing UBER, 17 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 30.0
# Implied volatility is: 62.45
#
# Processing TQQQ, 18 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 28.0
# Implied volatility is: 84.52
#
# Processing WBD, 19 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 12.5
# Implied volatility is: 62.79
#
# Processing CHPT, 20 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.0
# Implied volatility is: 74.12
#
# Processing PYPL, 21 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 95.0
# Implied volatility is: 55.75
#
# Processing NKLA, 22 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 100.0
#
# Processing INTC, 23 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 30.0
# Implied volatility is: 39.99
#
# Processing COIN, 24 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 75.0
# Implied volatility is: 102.28
#
# Processing EEM, 25 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 38.0
# Implied volatility is: 24.63
#
# Processing MSFT, 26 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 260.0
# Implied volatility is: 32.42
#
# Processing GOOGL, 27 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 107.5
# Implied volatility is: 38.75
#
# Processing HOOD, 28 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 79.49
#
# Processing XLF, 29 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 34.0
# Implied volatility is: 25.64
#
# Processing UVXY, 30 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 9.0
# Implied volatility is: 113.28
#
# Processing SNAP, 31 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 13.0
# Implied volatility is: 90.63
#
# Processing DIA, 32 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 320.0
# Implied volatility is: 20.32
#
# Processing EWW, 33 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 46.0
# Implied volatility is: 26.83
#
# Processing EWZ, 34 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 30.0
# Implied volatility is: 49.93
#
# Processing FXI, 35 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 29.0
# Implied volatility is: 32.64
#
# Processing GDX, 36 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 24.0
# Implied volatility is: 44.58
#
# Processing GDXJ, 37 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 30.0
# Implied volatility is: 48.93
#
# Processing GLD, 38 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 159.0
# Implied volatility is: 17.19
#
# Processing SLV, 39 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.0
# Implied volatility is: 30.27
#
# Processing SMH, 40 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 210.0
# Implied volatility is: 40.17
#
# Processing TLT, 41 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 108.0
# Implied volatility is: 22.96
#
# Processing USO, 42 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 68.0
# Implied volatility is: 51.93
#
# Processing VXX, 43 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 18.0
# Implied volatility is: 60.84
#
# Processing XLE, 44 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 79.0
# Implied volatility is: 37.73
#
# Processing XLU, 45 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 77.0
# Implied volatility is: 20.4
#
# Processing XOP, 46 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 140.0
# Implied volatility is: 48.76
#
# Processing IPOF, 47 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 6.93
#
# Processing IMPP, 48 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0.5
# Implied volatility is: 181.25
#
# Processing VYGG, 49 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 5.08
#
# Processing EBON, 50 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# EBON, 50 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000185C7500888>)
#
# Processing BKLN, 51 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 20.0
# Implied volatility is: 14.26
#
# Processing MEIP, 52 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 137.5
#
# Processing CCL, 53 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 78.22
#
# Processing IDEX, 54 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 175.0
#
# Processing BBD, 55 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 50.0
#
# Processing TIGR, 56 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 3.5
# Implied volatility is: 65.63
#
# Processing T, 57 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.0
# Implied volatility is: 24.56
#
# Processing PLTR, 58 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 8.0
# Implied volatility is: 70.7
#
# Processing CBIO, 59 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 64.06
#
# Processing AAL, 60 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 14.0
# Implied volatility is: 58.5
#
# Processing ET, 61 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 12.0
# Implied volatility is: 35.06
#
# Processing BAC, 62 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 35.0
# Implied volatility is: 34.79
#
# Processing BNGO, 63 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 140.23
#
# Processing ONEM, 64 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.5
# Implied volatility is: 7.62
#
# Processing EWG, 65 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.0
# Implied volatility is: 31.93
#
# Processing MNMD, 66 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 0.0
#
# Processing ANY, 67 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0.5
# Implied volatility is: 198.44
#
# Processing BIOR, 68 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 221.88
#
# Processing RIG, 69 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 83.59
#
# Processing PFE, 70 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 47.5
# Implied volatility is: 29.64
#
# Processing MMAT, 71 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 125.0
#
# Processing C, 72 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 50.0
# Implied volatility is: 32.57
#
# Processing MULN, 73 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 150.0
#
# Processing CGC, 74 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 108.98
#
# Processing AGNC, 75 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.0
# Implied volatility is: 20.41
#
# Processing KO, 76 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 62.5
# Implied volatility is: 20.2
#
# Processing EVFM, 77 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 50.0
#
# Processing TLRY, 78 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 100.39
#
# Processing NLY, 79 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.0
# Implied volatility is: 21.29
#
# Processing PLBY, 80 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 96.68
#
# Processing NRZ, 81 of 297...
# Closest expiry is: 2022-09-08
# NRZ, 81 not found.
# Exception is Expiration `2022-09-08` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-08` cannot be found. Available expiration are: []'), <traceback object at 0x00000185C6294188>)
#
# Processing NIO, 82 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.5
# Implied volatility is: 71.0
#
# Processing NYMT, 83 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 51.17
#
# Processing GOTU, 84 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.5
# Implied volatility is: 126.56
#
# Processing DS, 85 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# DS, 85 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x00000185C6294508>)
#
# Processing CTLP, 86 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 84.38
#
# Processing VRM, 87 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.0
# Implied volatility is: 132.03
#
# Processing HGEN, 88 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# HGEN, 88 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x00000185C7413048>)
#
# Processing AGEN, 89 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 695.31
#
# Processing ACRX, 90 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# ACRX, 90 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x00000185C73EF7C8>)
#
# Processing NMTR, 91 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# NMTR, 91 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x00000185C6298C48>)
#
# Processing CRNT, 92 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 54.69
#
# Processing OEG, 93 of 297...
# Closest expiry is: 2022-09-08
# OEG, 93 not found.
# Exception is Expiration `2022-09-08` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-09-08` cannot be found. Available expiration are: []'), <traceback object at 0x00000185C6183348>)
#
# Processing THCA, 94 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 56.74
#
# Processing CEI, 95 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# CEI, 95 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000185C6181FC8>)
#
# Processing RIOT, 96 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.0
# Implied volatility is: 120.9
#
# Processing WFC, 97 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 45.0
# Implied volatility is: 34.84
#
# Processing TRX, 98 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# TRX, 98 not found.
# Exception is 10
# Error is: (<class 'KeyError'>, KeyError(10), <traceback object at 0x00000185C722B208>)
#
# Processing BBIG, 99 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 159.38
#
# Processing NU, 100 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 78.91
#
# Processing CRBP, 101 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# CRBP, 101 not found.
# Exception is 7
# Error is: (<class 'KeyError'>, KeyError(7), <traceback object at 0x00000185C742CAC8>)
#
# Processing NCLH, 102 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 15.0
# Implied volatility is: 73.83
#
# Processing TEVA, 103 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 9.0
# Implied volatility is: 48.24
#
# Processing CSCO, 104 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 45.0
# Implied volatility is: 28.37
#
# Processing KGC, 105 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 54.69
#
# Processing PINS, 106 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 25.0
# Implied volatility is: 77.64
#
# Processing BITF, 107 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.5
# Implied volatility is: 140.63
#
# Processing FUBO, 108 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 4.0
# Implied volatility is: 122.85
#
# Processing LAZR, 109 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.5
# Implied volatility is: 87.5
#
# Processing ARCC, 110 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 20.0
# Implied volatility is: 19.14
#
# Processing UAL, 111 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 39.0
# Implied volatility is: 54.27
#
# Processing GOLD, 112 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 16.0
# Implied volatility is: 40.82
#
# Processing VALE, 113 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 12.0
# Implied volatility is: 51.32
#
# Processing FTCH, 114 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 92.38
#
# Processing CRU, 115 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 8.5
#
# Processing CLSN, 116 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 12.5
#
# Processing DNN, 117 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.5
# Implied volatility is: 84.38
#
# Processing KMI, 118 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 18.0
# Implied volatility is: 26.95
#
# Processing NAK, 119 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0.5
# Implied volatility is: 150.0
#
# Processing NNDM, 120 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 62.11
#
# Processing TSM, 121 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 80.0
# Implied volatility is: 36.41
#
# Processing CLVS, 122 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 226.56
#
# Processing VZ, 123 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 40.0
# Implied volatility is: 22.73
#
# Processing STLA, 124 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 12.5
# Implied volatility is: 46.97
#
# Processing DNA, 125 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 3.0
# Implied volatility is: 96.48
#
# Processing SAN, 126 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.0
# Implied volatility is: 62.5
#
# Processing PNNT, 127 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.5
# Implied volatility is: 31.25
#
# Processing FENG, 128 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 9.18
#
# Processing AGCB, 129 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 0.78
#
# Processing WISH, 130 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.0
# Implied volatility is: 114.84
#
# Processing GM, 131 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 40.0
# Implied volatility is: 47.29
#
# Processing ABEO, 132 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 12.5
#
# Processing ASHR, 133 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 30.0
# Implied volatility is: 21.92
#
# Processing PARA, 134 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 22.5
# Implied volatility is: 49.71
#
# Processing HTZ, 135 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 20.0
# Implied volatility is: 54.05
#
# Processing JBLU, 136 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 56.25
#
# Processing BCS, 137 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 44.34
#
# Processing CONX, 138 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 6.35
#
# Processing XOM, 139 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 95.0
# Implied volatility is: 38.32
#
# Processing AMRN, 140 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 275.0
#
# Processing GOCO, 141 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# GOCO, 141 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000185C751C088>)
#
# Processing CBAT, 142 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 109.38
#
# Processing AM, 143 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 33.4
#
# Processing MDVL, 144 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# MDVL, 144 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x00000185C7470AC8>)
#
# Processing BITO, 145 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 12.0
# Implied volatility is: 70.9
#
# Processing DKNG, 146 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.5
# Implied volatility is: 81.25
#
# Processing ATY, 147 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 57.42
#
# Processing UUP, 148 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 29.0
# Implied volatility is: 13.67
#
# Processing SIRI, 149 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 6.0
# Implied volatility is: 27.54
#
# Processing NOK, 150 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 38.67
#
# Processing KWEB, 151 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 28.0
# Implied volatility is: 51.78
#
# Processing PTON, 152 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 9.0
# Implied volatility is: 108.01
#
# Processing PIPP, 153 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 8.99
#
# Processing TRVG, 154 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 107.81
#
# Processing CLOV, 155 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 87.5
#
# Processing OXY, 156 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 65.0
# Implied volatility is: 57.09
#
# Processing MPW, 157 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 15.0
# Implied volatility is: 36.28
#
# Processing ACB, 158 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 1.5
# Implied volatility is: 92.19
#
# Processing NEM, 159 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 42.5
# Implied volatility is: 41.63
#
# Processing AMRX, 160 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 99.61
#
# Processing AXU, 161 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# AXU, 161 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000185C742CA48>)
#
# Processing HUT, 162 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.0
# Implied volatility is: 159.38
#
# Processing RUN, 163 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 37.5
# Implied volatility is: 84.06
#
# Processing GNUS, 164 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 143.75
#
# Processing CORZ, 165 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.0
# Implied volatility is: 117.58
#
# Processing TWTR, 166 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 42.0
# Implied volatility is: 71.8
#
# Processing NLOK, 167 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 23.0
# Implied volatility is: 36.72
#
# Processing DAL, 168 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 32.0
# Implied volatility is: 48.49
#
# Processing GLBS, 169 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 98.44
#
# Processing CLF, 170 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 18.0
# Implied volatility is: 63.53
#
# Processing ADVM, 171 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0
# ADVM, 171 not found.
# Exception is 6
# Error is: (<class 'KeyError'>, KeyError(6), <traceback object at 0x00000185C7470648>)
#
# Processing AEM, 172 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 45.0
# Implied volatility is: 47.05
#
# Processing TEF, 173 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 42.19
#
# Processing IPOD, 174 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 7.62
#
# Processing GFI, 175 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 8.0
# Implied volatility is: 51.76
#
# Processing AQMS, 176 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# AQMS, 176 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x00000185C7521508>)
#
# Processing JPM, 177 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 120.0
# Implied volatility is: 28.96
#
# Processing ITUB, 178 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 50.39
#
# Processing EWC, 179 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# EWC, 179 not found.
# Exception is index 1 is out of bounds for axis 0 with size 0
# Error is: (<class 'IndexError'>, IndexError('index 1 is out of bounds for axis 0 with size 0'), <traceback object at 0x00000185C615EA08>)
#
# Processing UEC, 180 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 4.5
# Implied volatility is: 98.63
#
# Processing UAMY, 181 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# UAMY, 181 not found.
# Exception is 8
# Error is: (<class 'KeyError'>, KeyError(8), <traceback object at 0x00000185C75001C8>)
#
# Processing AKBA, 182 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 168.75
#
# Processing DM, 183 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 3.5
# Implied volatility is: 94.92
#
# Processing LDI, 184 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 81.25
#
# Processing BEKE, 185 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 17.5
# Implied volatility is: 77.05
#
# Processing CS, 186 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 52.15
#
# Processing TBT, 187 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 29.0
# Implied volatility is: 44.29
#
# Processing OPEN, 188 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 95.31
#
# Processing LUMN, 189 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 43.95
#
# Processing EVOK, 190 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 44.53
#
# Processing FSK, 191 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 20.0
# Implied volatility is: 17.97
#
# Processing BODY, 192 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 89.06
#
# Processing UNIT, 193 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 9.0
# Implied volatility is: 43.16
#
# Processing SKLZ, 194 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.5
# Implied volatility is: 127.34
#
# Processing BB, 195 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 6.0
# Implied volatility is: 68.16
#
# Processing CIM, 196 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 34.47
#
# Processing M, 197 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 18.0
# Implied volatility is: 62.26
#
# Processing CPG, 198 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 63.28
#
# Processing BRFS, 199 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 68.75
#
# Processing LFLY, 200 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 120.31
#
# Processing SWN, 201 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 69.24
#
# Processing LCID, 202 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 15.0
# Implied volatility is: 73.83
#
# Processing FCX, 203 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 31.0
# Implied volatility is: 56.06
#
# Processing BTI, 204 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 40.0
# Implied volatility is: 20.34
#
# Processing YSG, 205 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# YSG, 205 not found.
# Exception is 5
# Error is: (<class 'KeyError'>, KeyError(5), <traceback object at 0x00000185C722B788>)
#
# Processing DIS, 206 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 110.0
# Implied volatility is: 37.76
#
# Processing HL, 207 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 4.0
# Implied volatility is: 59.77
#
# Processing MARA, 208 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 12.5
# Implied volatility is: 121.88
#
# Processing AYRO, 209 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# AYRO, 209 not found.
# Exception is 4
# Error is: (<class 'KeyError'>, KeyError(4), <traceback object at 0x00000185C731D508>)
#
# Processing EFA, 210 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 61.0
# Implied volatility is: 23.37
#
# Processing MO, 211 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 45.0
# Implied volatility is: 20.22
#
# Processing ATUS, 212 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 71.48
#
# Processing XSPA, 213 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 117.19
#
# Processing DRRX, 214 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# DRRX, 214 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000185C73EFC88>)
#
# Processing SFT, 215 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# SFT, 215 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000185C73EF4C8>)
#
# Processing GDRX, 216 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 76.76
#
# Processing BEST, 217 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# BEST, 217 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x00000185C73A8448>)
#
# Processing UXIN, 218 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 153.13
#
# Processing YVR, 219 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# YVR, 219 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000185C7413C88>)
#
# Processing SFL, 220 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 32.32
#
# Processing BMY, 221 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 70.0
# Implied volatility is: 24.15
#
# Processing GORO, 222 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 82.81
#
# Processing BIRD, 223 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 88.09
#
# Processing NILE, 224 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 0.5
# Implied volatility is: 118.75
#
# Processing GILT, 225 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 50.0
#
# Processing CCJ, 226 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 30.0
# Implied volatility is: 62.72
#
# Processing BP, 227 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 31.0
# Implied volatility is: 37.18
#
# Processing ATAI, 228 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 5.0
# Implied volatility is: 75.78
#
# Processing ALZN, 229 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# ALZN, 229 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000185C6168288>)
#
# Processing FATH, 230 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 73.44
#
# Processing PLG, 231 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 134.38
#
# Processing FSM, 232 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 2.5
# Implied volatility is: 67.58
#
# Processing UDN, 233 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 18.0
# Implied volatility is: 13.43
#
# Processing ARKK, 234 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 43.0
# Implied volatility is: 56.81
#
# Processing AUY, 235 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 4.5
# Implied volatility is: 53.91
#
# Processing RNWK, 236 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# RNWK, 236 not found.
# Exception is 5
# Error is: (<class 'KeyError'>, KeyError(5), <traceback object at 0x00000185C6181D48>)
#
# Processing CLNE, 237 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.0
# Implied volatility is: 72.85
#
# Processing CLVR, 238 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# CLVR, 238 not found.
# Exception is 6
# Error is: (<class 'KeyError'>, KeyError(6), <traceback object at 0x00000185C731DE48>)
#
# Processing AGI, 239 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 7.5
# Implied volatility is: 51.76
#
# Processing LYFT, 240 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 17.5
# Implied volatility is: 73.24
#
# Processing AVTR, 241 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 27.5
# Implied volatility is: 40.63
#
# Processing MP, 242 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 35.0
# Implied volatility is: 62.4
#
# Processing VTNR, 243 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 93.36
#
# Processing CLSK, 244 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 110.16
#
# Processing GOEV, 245 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 2.5
# Implied volatility is: 99.22
#
# Processing KERN, 246 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# KERN, 246 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x00000185C7500148>)
#
# Processing LVS, 247 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 38.0
# Implied volatility is: 50.0
#
# Processing BOXD, 248 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 1.0
# Implied volatility is: 154.69
#
# Processing MRO, 249 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 26.0
# Implied volatility is: 56.1
#
# Processing TTOO, 250 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# TTOO, 250 not found.
# Exception is 15
# Error is: (<class 'KeyError'>, KeyError(15), <traceback object at 0x00000185C72690C8>)
#
# Processing STWD, 251 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 23.0
# Implied volatility is: 22.05
#
# Processing CVE, 252 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 18.0
# Implied volatility is: 54.93
#
# Processing RKT, 253 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 8.0
# Implied volatility is: 59.86
#
# Processing HMLP, 254 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 10.0
# Implied volatility is: 18.26
#
# Processing KOS, 255 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 5.0
# Implied volatility is: 86.72
#
# Processing RVNC, 256 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 25.0
# Implied volatility is: 69.78
#
# Processing CLR, 257 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 70.0
# Implied volatility is: 37.93
#
# Processing PLAY, 258 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 40.0
# Implied volatility is: 54.3
#
# Processing ALT, 259 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 19.0
# Implied volatility is: 145.8
#
# Processing BOIL, 260 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 77.0
# Implied volatility is: 181.27
#
# Processing PTEN, 261 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 14.0
# Implied volatility is: 69.24
#
# Processing ASAN, 262 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 25.0
# Implied volatility is: 84.08
#
# Processing TAN, 263 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 90.0
# Implied volatility is: 43.99
#
# Processing SHEL, 264 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 52.5
# Implied volatility is: 34.69
#
# Processing ENPH, 265 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 320.0
# Implied volatility is: 72.31
#
# Processing MMM, 266 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 120.0
# Implied volatility is: 34.75
#
# Processing SPWR, 267 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 28.0
# Implied volatility is: 72.53
#
# Processing ASO, 268 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 47.0
# Implied volatility is: 50.85
#
# Processing STEM, 269 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 15.0
# Implied volatility is: 88.87
#
# Processing BLNK, 270 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 21.0
# Implied volatility is: 72.71
#
# Processing ULTA, 271 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 445.0
# Implied volatility is: 40.21
#
# Processing LULU, 272 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 350.0
# Implied volatility is: 44.73
#
# Processing CHRW, 273 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 115.0
# Implied volatility is: 33.63
#
# Processing GSAT, 274 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.5
# Implied volatility is: 101.56
#
# Processing FAZE, 275 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 12.5
# Implied volatility is: 73.83
#
# Processing HD, 276 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 300.0
# Implied volatility is: 29.76
#
# Processing TRQ, 277 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 32.0
# Implied volatility is: 34.99
#
# Processing GLW, 278 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 33.0
# Implied volatility is: 34.33
#
# Processing VUZI, 279 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 8.0
# Implied volatility is: 69.53
#
# Processing FLEX, 280 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 19.0
# Implied volatility is: 41.21
#
# Processing VSTO, 281 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 27.5
# Implied volatility is: 53.47
#
# Processing BAX, 282 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 57.5
# Implied volatility is: 34.94
#
# Processing GME, 283 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 26.25
# Implied volatility is: 95.21
#
# Processing AEO, 284 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 11.0
# Implied volatility is: 57.13
#
# Processing PEP, 285 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 175.0
# Implied volatility is: 21.58
#
# Processing SEDG, 286 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 310.0
# Implied volatility is: 64.12
#
# Processing BHC, 287 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 7.0
# Implied volatility is: 109.38
#
# Processing UCO, 288 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 29.75
# Implied volatility is: 91.6
#
# Processing HST, 289 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 18.0
# Implied volatility is: 37.11
#
# Processing ARRY, 290 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 22.5
# Implied volatility is: 91.65
#
# Processing RH, 291 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 260.0
# Implied volatility is: 62.48
#
# Processing SO, 292 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 80.0
# Implied volatility is: 22.01
#
# Processing SPXS, 293 of 297...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.0
# Implied volatility is: 68.56
#
# Processing KHC, 294 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 35.0
# Implied volatility is: 32.59
#
# Processing DG, 295 of 297...
# Closest expiry is: 2022-11-18
# Closest strike price is: 250.0
# Implied volatility is: 26.4
#
# Processing MTCH, 296 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 60.0
# Implied volatility is: 59.35
#
# Processing ADM, 297 of 297...
# Closest expiry is: 2022-12-16
# Closest strike price is: 90.0
# Implied volatility is: 32.36

# %%
print('Completed.')
# Out:
# Completed.

# %% [markdown]
# Create a dataframe for the implied volatility data.

# %%
iv_dictionary = {
    'ticker':ticker_list2,
    'expiry':expiry_list,
    'strike':strike_list,
    'implied_vol':iv_list
}

iv_df = pd.DataFrame(iv_dictionary)
iv_df["implied_vol"] = iv_df["implied_vol"].astype(str).astype(float)
iv_df = iv_df.sort_values(['implied_vol'],ascending=False)
iv_df.to_csv('../0_data_dump/optionistics/implied_vols.csv')
print(f'Size of iv_df is {len(iv_df)}.')
iv_df.head(3)
# Out:
# Size of iv_df is 268.
#     ticker      expiry  strike  implied_vol
# 83    AGEN  2022-11-18     2.5       695.31
# 128   AMRN  2022-11-18     1.0       275.00
# 110   CLVS  2022-10-21     1.0       226.56

# %%
print('Completed.')
# Out:
# Completed.

# %%
# for col in final_df.columns:
#     print(col)

# %%
final_df = pd.merge(cheap_df,finviz_df,on='ticker',how='left')
print(len(final_df))
final_df = pd.merge(final_df,optionistics_data,on='ticker',how='outer')
print(len(final_df))
final_df = pd.merge(final_df,iv_df,on='ticker',how='outer')
print(len(final_df))

final_df['iv_premium'] = final_df['implied_vol'] - final_df['realized_vol']

final_df['iv_prem_pt'] = 0
final_df['iv_prem_pt'] = np.select(condlist=[(final_df['iv_premium']>final_df['iv_premium'].quantile(0.85))],
                           choicelist=[1],
                           default=0)

final_df['oi_pct_chg_pts'] = final_df['oi_pct_chg_pts'].fillna(0)
final_df['cheap_pt'] = final_df['cheap_pt'].fillna(0)
final_df['total_pts'] = final_df['cheap_pt'] + final_df['float_short_pt'] + final_df['oi_pct_chg_pts'] + final_df['iv_prem_pt']
final_df = final_df[['ticker','expiry','strike','total_pts','iv_prem_pt','cheap_pt','oi_pct_chg_pts','float_short_pt','iv_premium','avg_pct','float_short','oi_pct_chg','p_c_ratio']]
final_df = final_df.sort_values(by = ['total_pts','float_short'],ascending=[False,False])
final_df = final_df[final_df['total_pts'] > 0]
final_df.to_csv('../0_data_dump/asset_screener/options_output.csv')
final_df.head(20)
# Out:
# 297
# 297
# 297
#     ticker      expiry  strike  total_pts  iv_prem_pt  cheap_pt  \
# 57    NKLA  2022-11-18    5.00        4.0           1         1
# 56     GME  2022-11-18   26.25        4.0           1         1
# 23    WISH  2022-12-16    1.00        3.0           1         1
# 256    ALT  2022-11-18   19.00        3.0           1         0
# 20    VSTO  2022-11-18   27.50        3.0           0         1
# 71    CHRW  2022-11-18  115.00        3.0           0         1
# 295   FAZE  2022-10-21   12.50        2.0           0         0
# 175   SPWR  2022-12-16   28.00        2.0           0         0
# 10    SIRI  2022-11-18    6.00        2.0           0         1
# 125   VUZI  2022-10-21    8.00        2.0           0         0
# 241   BLNK  2022-11-18   21.00        2.0           0         0
# 191   CLVS  2022-10-21    1.00        2.0           1         0
# 72    ASAN  2022-11-18   25.00        2.0           0         0
# 140   SKLZ  2022-11-18    1.50        2.0           1         0
# 226    AEO  2022-11-18   11.00        2.0           0         0
# 24    LUMN  2022-11-18   10.00        2.0           0         1
# 281   BNGO  2022-11-18    2.50        2.0           1         0
# 176    ASO  2022-11-18   47.00        2.0           0         0
# 123   GNUS  2022-10-21    0.50        2.0           1         0
# 133   PLAY  2022-11-18   40.00        2.0           0         0
#
#      oi_pct_chg_pts  float_short_pt  iv_premium  avg_pct  float_short  \
# 57              1.0             1.0       24.63   -13.31        30.07
# 56              1.0             1.0       25.01   -13.51        20.72
# 23              0.0             1.0       43.14   -45.88        10.66
# 256             1.0             1.0       53.71   114.73        10.40
# 20              1.0             1.0       21.22   -49.17         9.30
# 71              1.0             1.0        5.63    -1.84         8.40
# 295             1.0             1.0     -129.71   518.92        39.95
# 175             1.0             1.0       -2.28    55.70        38.54
# 10              0.0             1.0        9.00   -89.37        29.64
# 125             1.0             1.0      -10.19    32.36        26.99
# 241             1.0             1.0      -12.46    96.34        26.69
# 191             0.0             1.0      110.27    63.66        20.83
# 72              1.0             1.0      -17.82     0.56        18.10
# 140             0.0             1.0       29.84    37.02        17.81
# 226             1.0             1.0       -1.86    86.54        15.29
# 24              0.0             1.0       14.49   -45.86        15.22
# 281             0.0             1.0       21.29   172.24        13.75
# 176             1.0             1.0        0.44    56.18        13.17
# 123             0.0             1.0       70.38    30.63        13.11
# 133             1.0             1.0        1.18    34.43        12.43
#
#      oi_pct_chg  p_c_ratio
# 57         8.58       0.92
# 56         7.06       1.27
# 23          NaN        NaN
# 256       30.49       0.44
# 20         7.62       2.10
# 71         9.27       0.60
# 295        8.49       0.79
# 175       11.08       0.65
# 10          NaN        NaN
# 125        8.22       0.60
# 241        9.89       1.03
# 191         NaN        NaN
# 72        18.59       0.66
# 140         NaN        NaN
# 226        7.02       0.78
# 24          NaN        NaN
# 281         NaN        NaN
# 176       10.50       0.82
# 123         NaN        NaN
# 133       36.94       1.21

# %%
toc = time.perf_counter()
total_time = toc - tic

print(f'Program completed in {round(total_time,2)} seconds or {round(total_time/60,2)} minutes on {datetime.datetime.now()}.')
# Out:
# Program completed in 219.41 seconds or 3.66 minutes on 2022-09-08 22:36:28.123691.
