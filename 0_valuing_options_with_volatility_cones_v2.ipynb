# %% [markdown]
# # Options Screener
#
# This notebook is meant to analyze a list of tickers and output which tickers have the highest value call options with the highest probability of increasing in value in the short-term.
#
# Manual steps procedure:
# - Update options_list2.csv with the latest OI pct changes from Optionistics.com using the options_list_compare.xlsx file
# - Get the latest finviz file from the local directory
#
# This screener looks at the following attributes:
# - Whether an option is 'cheap' i.e. has low realized volatility compared to its historical realized volatility, the lowest 15% are given a point
# - Implied volatility premium or discount, the top 15% are given a point
# - Open interest % change from optionistics, these are given a point
# - Highest float short percent, the top 15% are given a point

# %%
# %matplotlib inline

import math
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

tickers_df = pd.read_csv('../0_inputs/asset_screeners/options_list1.csv')
optionistics_data = pd.read_csv('../0_inputs/asset_screeners/options_list2.csv')
# optionistics_data.head(3)

ticker_dictionary = {
    'VIX':'^VIX'
}

ticker_list_df = pd.merge(tickers_df[['ticker']],optionistics_data[['ticker']],on='ticker',how='outer')

ticker_list = ticker_list_df['ticker'].to_list()

# %%
def realized_vol(price_data, window=30):

#     print(price_data.tail(5))
    log_return = (price_data["Close"] / price_data["Close"].shift(1)).apply(np.log)

    return log_return.rolling(window=window, center=False).std() * math.sqrt(252)

# %%
windows = [30, 60, 90, 120]
quantiles = [0.25, 0.75]

min_ = []
max_ = []
median = []
top_q = []
bottom_q = []
realized = []

# %%
completed_tkr_list = []
realized_vol_list = []
avg_pct_list = []
pct30_list = []
pct60_list = []
pct90_list = []
pct120_list = []
counter = 1

cur_price_dict = {}

# ticker_list = ['AAPL','TSLA','MSFT'] # test list

for ticker in ticker_list:

    print(f"Processing {ticker}, {counter} of {len(ticker_list)}...")
    # data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")

    # start="2020-01-01", end="2020-12-31"

    # start_date = '2020-01-01'
    # end_date = '2020-12-31'
    
    if ticker in ticker_dictionary:
        tkr = ticker_dictionary[ticker]
    else: tkr = ticker

    data = yf.download(  # or pdr.get_data_yahoo(...
            # tickers list or string as well
            tickers = tkr,

            # use "period" instead of start/end
            # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
            # (optional, default is '1mo')
            period = "1y",

    #         start = start_date,
    #         end = end_date,

            # fetch data by interval (including intraday if period < 60 days)
            # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
            # (optional, default is '1d')
            interval = "1d",

            # group by ticker (to access via data['SPY'])
            # (optional, default is 'column')
            group_by = 'ticker',

            # adjust all OHLC automatically
            # (optional, default is False)
            auto_adjust = True,

            # download pre/post regular market hours data
            # (optional, default is False)
            prepost = True,

            # use threads for mass downloading? (True/False/Integer)
            # (optional, default is True)
            threads = True,

            # proxy URL scheme use use when downloading?
            # (optional, default is None)
            proxy = None
        )

    # data.to_csv('BTC_1hr_prices.csv')
    # data.head(3)
#     print(data.tail(5))

    cur_price_dict[ticker] = data['Close'][-1]

    min_ = []
    max_ = []
    median = []
    top_q = []
    bottom_q = []
    realized = []

    for window in windows:

        # get a dataframe with realized volatility
        estimator = realized_vol(window=window, price_data=data)
#         print(estimator)

        # append the summary stats to a list
        min_.append(estimator.min())
        max_.append(estimator.max())
        median.append(estimator.median())
        top_q.append(estimator.quantile(quantiles[1]))
        bottom_q.append(estimator.quantile(quantiles[0]))
        realized.append(estimator[-1])
#         print(min_)

    pct_list = []

    pct30 = (realized[0] - bottom_q[0]) / (top_q[0] - bottom_q[0]) * 100
    pct_list.append(pct30)
    pct60 = (realized[1] - bottom_q[1]) / (top_q[1] - bottom_q[1]) * 100
    pct_list.append(pct60)
    pct90 = (realized[2] - bottom_q[2]) / (top_q[2] - bottom_q[2]) * 100
    pct_list.append(pct90)
    pct120 = (realized[3] - bottom_q[3]) / (top_q[3] - bottom_q[3]) * 100
    pct_list.append(pct120)

#     print(pct30)
#     print(pct60)
#     print(pct90)
#     print(pct120)
#     print(pct_list)

    avg_pct = sum(pct_list)/len(pct_list)
#     print(avg_pct)
    
    completed_tkr_list.append(ticker)
    realized_vol_list.append(round(realized[1] * 100,2)) # this is realized vol for 60 day window
    avg_pct_list.append(round(avg_pct,2))
    pct30_list.append(round(pct30,2))
    pct60_list.append(round(pct60,2))
    pct90_list.append(round(pct90,2))
    pct120_list.append(round(pct120,2))
    
    counter += 1
# Out:
# Processing SPY, 1 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing QQQ, 2 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SPXU, 3 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AAPL, 4 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AMZN, 5 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TSLA, 6 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AMD, 7 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VIX, 8 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing IWM, 9 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HYG, 10 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing META, 11 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NVDA, 12 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AMC, 13 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing F, 14 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BABA, 15 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SOFI, 16 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UBER, 17 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TQQQ, 18 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing WBD, 19 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CHPT, 20 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PYPL, 21 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NKLA, 22 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing INTC, 23 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing COIN, 24 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EEM, 25 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MSFT, 26 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GOOGL, 27 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HOOD, 28 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing XLF, 29 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UVXY, 30 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SNAP, 31 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DIA, 32 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EWW, 33 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EWZ, 34 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FXI, 35 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GDX, 36 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GDXJ, 37 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GLD, 38 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SLV, 39 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SMH, 40 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TLT, 41 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing USO, 42 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VXX, 43 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing XLE, 44 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing XLU, 45 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing XOP, 46 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing IPOF, 47 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing IMPP, 48 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VYGG, 49 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EBON, 50 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BKLN, 51 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MEIP, 52 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CCL, 53 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing IDEX, 54 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BBD, 55 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TIGR, 56 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing T, 57 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PLTR, 58 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CBIO, 59 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AAL, 60 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ET, 61 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BAC, 62 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BNGO, 63 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ONEM, 64 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EWG, 65 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MNMD, 66 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ANY, 67 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BIOR, 68 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing RIG, 69 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PFE, 70 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MMAT, 71 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing C, 72 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MULN, 73 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CGC, 74 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AGNC, 75 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing KO, 76 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EVFM, 77 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TLRY, 78 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NLY, 79 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PLBY, 80 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NRZ, 81 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NIO, 82 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NYMT, 83 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GOTU, 84 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DS, 85 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CTLP, 86 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VRM, 87 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HGEN, 88 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AGEN, 89 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ACRX, 90 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NMTR, 91 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CRNT, 92 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing OEG, 93 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing THCA, 94 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CEI, 95 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing RIOT, 96 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing WFC, 97 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TRX, 98 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BBIG, 99 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NU, 100 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CRBP, 101 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NCLH, 102 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TEVA, 103 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CSCO, 104 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing KGC, 105 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PINS, 106 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BITF, 107 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FUBO, 108 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LAZR, 109 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ARCC, 110 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UAL, 111 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GOLD, 112 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VALE, 113 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FTCH, 114 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CRU, 115 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLSN, 116 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DNN, 117 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing KMI, 118 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NAK, 119 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NNDM, 120 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TSM, 121 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLVS, 122 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VZ, 123 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing STLA, 124 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DNA, 125 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SAN, 126 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PNNT, 127 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FENG, 128 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AGCB, 129 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing WISH, 130 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GM, 131 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ABEO, 132 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ASHR, 133 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PARA, 134 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HTZ, 135 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing JBLU, 136 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BCS, 137 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CONX, 138 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing XOM, 139 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AMRN, 140 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GOCO, 141 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CBAT, 142 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AM, 143 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MDVL, 144 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BITO, 145 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DKNG, 146 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ATY, 147 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UUP, 148 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SIRI, 149 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NOK, 150 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing KWEB, 151 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PTON, 152 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PIPP, 153 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TRVG, 154 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLOV, 155 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing OXY, 156 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MPW, 157 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ACB, 158 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NEM, 159 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AMRX, 160 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AXU, 161 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HUT, 162 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing RUN, 163 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GNUS, 164 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CORZ, 165 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TWTR, 166 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NLOK, 167 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DAL, 168 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GLBS, 169 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLF, 170 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ADVM, 171 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AEM, 172 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TEF, 173 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing IPOD, 174 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GFI, 175 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AQMS, 176 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing JPM, 177 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ITUB, 178 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EWC, 179 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UEC, 180 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UAMY, 181 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AKBA, 182 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DM, 183 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LDI, 184 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BEKE, 185 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CS, 186 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TBT, 187 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing OPEN, 188 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LUMN, 189 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EVOK, 190 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FSK, 191 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BODY, 192 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UNIT, 193 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SKLZ, 194 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BB, 195 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CIM, 196 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing M, 197 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CPG, 198 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BRFS, 199 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LFLY, 200 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SWN, 201 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LCID, 202 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FCX, 203 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BTI, 204 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing YSG, 205 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DIS, 206 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HL, 207 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MARA, 208 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AYRO, 209 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EFA, 210 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MO, 211 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ATUS, 212 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing XSPA, 213 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DRRX, 214 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SFT, 215 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GDRX, 216 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BEST, 217 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UXIN, 218 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing YVR, 219 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SFL, 220 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BMY, 221 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GORO, 222 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BIRD, 223 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NILE, 224 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GILT, 225 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CCJ, 226 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BP, 227 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ATAI, 228 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ALZN, 229 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FATH, 230 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PLG, 231 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FSM, 232 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing UDN, 233 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ARKK, 234 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AUY, 235 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing RNWK, 236 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLNE, 237 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLVR, 238 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AGI, 239 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LYFT, 240 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AVTR, 241 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MP, 242 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing VTNR, 243 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CLSK, 244 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GOEV, 245 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing KERN, 246 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing LVS, 247 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BOXD, 248 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MRO, 249 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TTOO, 250 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing STWD, 251 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CVE, 252 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing RKT, 253 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HMLP, 254 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GBT, 255 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ACWI, 256 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NEOG, 257 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing KRTX, 258 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CSTM, 259 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing STEM, 260 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing AES, 261 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DASH, 262 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TWLO, 263 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TIP, 264 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing TEAM, 265 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NOVA, 266 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CEG, 267 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PACB, 268 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CVNA, 269 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MMM, 270 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing EXPE, 271 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DUK, 272 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DOCS, 273 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing YETI, 274 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing GPRO, 275 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing APDN, 276 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing ARRY, 277 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing FTNT, 278 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MQ, 279 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NET, 280 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing PFSI, 281 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing RDFN, 282 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing NLSN, 283 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing DDOG, 284 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing MNST, 285 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing K, 286 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing HST, 287 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BKKT, 288 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SOXL, 289 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing CDEV, 290 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BIG, 291 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing SKT, 292 of 293...
# [*********************100%***********************]  1 of 1 completed
# Processing BYND, 293 of 293...
# [*********************100%***********************]  1 of 1 completed

# %%
import pandas as pd

pct_dictionary = {
    'ticker':completed_tkr_list,
    'realized_vol':realized_vol_list,
    'avg_pct':avg_pct_list,
    'pct30':pct30_list,
    'pct60':pct60_list,
    'pct90':pct90_list,
    'pct120':pct120_list
}

cheap_df = pd.DataFrame(pct_dictionary)
cheap_df = cheap_df.sort_values(['avg_pct'])
cheap_df.to_csv('../0_data_dump/optionistics/realized_vol.csv')
cheap_df
# Out:
#     ticker  realized_vol  avg_pct    pct30    pct60    pct90   pct120
# 47    IMPP        159.91  -338.65   -34.76    -5.06  -191.99 -1122.77
# 173   IPOD          2.35  -246.54  -272.65  -373.59  -135.51  -204.39
# 188   LUMN         39.67  -196.65   -12.78    16.47     1.52  -791.81
# 29    UVXY         87.49  -195.50   -80.96  -446.54   -64.05  -190.43
# 224   GILT         33.04  -142.33   -77.45    -7.98   -40.24  -443.64
# ..     ...           ...      ...      ...      ...      ...      ...
# 254    GBT        108.21   493.74   386.02   358.17   582.08   648.69
# 245   KERN        183.16   532.59   615.24   497.67   414.60   602.83
# 102   TEVA         69.55   651.04   437.04  1003.68   608.48   554.94
# 87    HGEN        345.94   822.11   971.40  1004.34   609.80   702.89
# 275   APDN        321.35  3498.64  2132.36  5000.87  3394.93  3466.39
#
# [293 rows x 7 columns]

# %%
import glob
import os

# Get the latest file from the directory
list_of_files = glob.glob('../0_inputs/asset_screeners/Finviz_Data/*') # * means all if need specific format then *.csv
latest_file = max(list_of_files, key=os.path.getctime)
print(latest_file)
# Out:
# ../0_inputs/asset_screeners/Finviz_Data\finviz (42).csv

# %%
import pandas as pd
import numpy as np

col_names = {
    'Ticker':'ticker',
    'Float Short':'float_short'
}

# Bring finviz.csv file into dataframe
finviz_df = pd.read_csv(latest_file)
finviz_df = finviz_df.rename(columns=col_names)
finviz_df = finviz_df[['ticker','float_short']]
finviz_df['float_short'] = finviz_df['float_short'].str.slice(0,-1) # remove the % character from the end of the string
finviz_df['float_short'] = finviz_df['float_short'].astype(str).astype(float) # convert to float for proper sorting
finviz_df = finviz_df.sort_values(['float_short'],ascending=False)

# Add Relative Volume Logic here
finviz_df['float_short_pt'] = 0
finviz_df['float_short_pt'] = np.select(condlist=[(finviz_df['float_short']>finviz_df['float_short'].quantile(0.85))],
                           choicelist=[1],
                           default=0)

# finviz_df = finviz_df[finviz_df['float_short'] > finviz_df['float_short'].quantile(.85)]
# finviz_df2 = finviz_df[finviz_df['float_short_pt']==1]
finviz_df.head(3)
# Out:
#      ticker  float_short  float_short_pt
# 6446    REV        86.52               1
# 3662   HRTX        56.39               1
# 730    BBBY        41.73               1

# %%
# Optional for if internet is running slow
# cheap_df = pd.read_csv('../0_data_dump/optionistics/realized_vol_output.csv')
# cheap_df = cheap_df.drop('Unnamed: 0', axis=1)

# Add Relative Volume Logic here
cheap_df['cheap_pt'] = 0
cheap_df['cheap_pt'] = np.select(condlist=[(cheap_df['avg_pct'] < 0)],
                           choicelist=[1],
                           default=0)

cheap_df.head(3)
# Out:
#     ticker  realized_vol  avg_pct   pct30   pct60   pct90   pct120  cheap_pt
# 47    IMPP        159.91  -338.65  -34.76   -5.06 -191.99 -1122.77         1
# 173   IPOD          2.35  -246.54 -272.65 -373.59 -135.51  -204.39         1
# 188   LUMN         39.67  -196.65  -12.78   16.47    1.52  -791.81         1

# %% [markdown]
# Implied volatility premium or discount calculations here.

# %%
import yfinance as yf
import datetime
import sys

today_date = datetime.datetime.now()
target_date = today_date + datetime.timedelta(days=60)

# ticker_list = ['AAPL','TSLA','MSFT'] # test list

ticker_list2 = []
expiry_list = []
strike_list = []
iv_list = []
counter = 1

for ticker in ticker_list:
    
    try:
        print(f'\nProcessing {ticker}, {counter} of {len(ticker_list)}...')
        
        # options_data = yf.Ticker("MSFT") # test input
        options_data = yf.Ticker(ticker)
        option_dates_list = options_data.options

        closest_date = today_date

        for x in option_dates_list:
            x = datetime.datetime.strptime(x, '%Y-%m-%d')
        #     print(x,',',(x-target_date).days)
            if (abs((x - target_date).days)) < abs(((closest_date - target_date).days)):
                closest_date = x

        # print(closest_date)
        # days_to_expiration = (closest_date - today_date).days
        # print(days_to_expiration)
        closest_date = closest_date.strftime("%Y-%m-%d")
        print(f'Closest expiry is: {closest_date}')

        opt = options_data.option_chain(closest_date)
        strike_price_np_array = opt[0]['strike'].to_numpy()

        if ticker in cur_price_dict:
            cur_price = cur_price_dict[ticker]
        else:
            data = yf.download(
                tickers = tkr,
                period = "5d",
                interval = "1d",
                group_by = 'ticker',
                auto_adjust = True,
                prepost = True,
                threads = True,
                proxy = None
            )
            cur_price = data['Close'][-1]
        
#         cur_price = 280 # test input
        closest_strike = 0

        strike_ctr = 0
        
        for x in strike_price_np_array:
            if abs(cur_price - x) < abs(cur_price - closest_strike):
                closest_strike = x
                strike_index = strike_ctr
            strike_ctr += 1

        print(f'Closest strike price is: {closest_strike}')

        strike_df = opt[0][opt[0]['strike']==closest_strike]
        implied_vol = round(strike_df['impliedVolatility'][strike_index] * 100,2)
        print(f'Implied volatility is: {implied_vol}')

        ticker_list2.append(ticker)
        expiry_list.append(closest_date)
        strike_list.append(closest_strike)
        iv_list.append(implied_vol)
        counter += 1
    
    except Exception as e:
        print(f'{ticker}, {counter} not found.')
        print(f'Exception is {e}')
        print(f'Error is: {sys.exc_info()}')
        counter += 1
# Out:
# Processing SPY, 1 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 413.0
# Implied volatility is: 19.98
#
# Processing QQQ, 2 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 322.0
# Implied volatility is: 26.6
#
# Processing SPXU, 3 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 15.0
# Implied volatility is: 58.79
#
# Processing AAPL, 4 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 165.0
# Implied volatility is: 29.36
#
# Processing AMZN, 5 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 140.0
# Implied volatility is: 37.19
#
# Processing TSLA, 6 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 860.0
# Implied volatility is: 59.06
#
# Processing AMD, 7 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 100.0
# Implied volatility is: 50.06
#
# Processing VIX, 8 of 293...
# Closest expiry is: 2022-08-06
# VIX, 8 not found.
# Exception is Expiration `2022-08-06` cannot be found. Available expiration are: []
# Error is: (<class 'ValueError'>, ValueError('Expiration `2022-08-06` cannot be found. Available expiration are: []'), <traceback object at 0x00000282FB631C08>)
#
# Processing IWM, 9 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 191.0
# Implied volatility is: 24.87
#
# Processing HYG, 10 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 78.0
# Implied volatility is: 10.91
#
# Processing META, 11 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 165.0
# Implied volatility is: 45.29
#
# Processing NVDA, 12 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 190.0
# Implied volatility is: 52.62
#
# Processing AMC, 13 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.0
# Implied volatility is: 128.91
#
# Processing F, 14 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 15.0
# Implied volatility is: 41.6
#
# Processing BABA, 15 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 95.0
# Implied volatility is: 54.72
#
# Processing SOFI, 16 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 68.75
#
# Processing UBER, 17 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 32.5
# Implied volatility is: 52.73
#
# Processing TQQQ, 18 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 35.0
# Implied volatility is: 76.37
#
# Processing WBD, 19 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 15.0
# Implied volatility is: 57.42
#
# Processing CHPT, 20 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 16.0
# Implied volatility is: 77.64
#
# Processing PYPL, 21 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 95.0
# Implied volatility is: 48.52
#
# Processing NKLA, 22 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 8.0
# Implied volatility is: 83.59
#
# Processing INTC, 23 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 35.0
# Implied volatility is: 34.82
#
# Processing COIN, 24 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 95.0
# Implied volatility is: 109.11
#
# Processing EEM, 25 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 40.0
# Implied volatility is: 21.78
#
# Processing MSFT, 26 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 285.0
# Implied volatility is: 27.14
#
# Processing GOOGL, 27 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 117.5
# Implied volatility is: 32.12
#
# Processing HOOD, 28 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 74.41
#
# Processing XLF, 29 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 34.0
# Implied volatility is: 22.68
#
# Processing UVXY, 30 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 128.61
#
# Processing SNAP, 31 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 85.06
#
# Processing DIA, 32 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 328.0
# Implied volatility is: 16.27
#
# Processing EWW, 33 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 45.0
# Implied volatility is: 26.07
#
# Processing EWZ, 34 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 30.0
# Implied volatility is: 40.09
#
# Processing FXI, 35 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 30.0
# Implied volatility is: 30.86
#
# Processing GDX, 36 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 26.0
# Implied volatility is: 40.82
#
# Processing GDXJ, 37 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 34.0
# Implied volatility is: 45.26
#
# Processing GLD, 38 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 165.0
# Implied volatility is: 16.63
#
# Processing SLV, 39 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 18.5
# Implied volatility is: 27.78
#
# Processing SMH, 40 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 245.0
# Implied volatility is: 35.18
#
# Processing TLT, 41 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 116.0
# Implied volatility is: 20.14
#
# Processing USO, 42 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 72.0
# Implied volatility is: 47.36
#
# Processing VXX, 43 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 21.0
# Implied volatility is: 51.56
#
# Processing XLE, 44 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 75.0
# Implied volatility is: 35.68
#
# Processing XLU, 45 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 74.0
# Implied volatility is: 23.85
#
# Processing XOP, 46 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 130.0
# Implied volatility is: 46.79
#
# Processing IPOF, 47 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 6.54
#
# Processing IMPP, 48 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 159.38
#
# Processing VYGG, 49 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 5.67
#
# Processing EBON, 50 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# EBON, 50 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000282F8F19208>)
#
# Processing BKLN, 51 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 21.0
# Implied volatility is: 10.74
#
# Processing MEIP, 52 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 1.0
# Implied volatility is: 168.75
#
# Processing CCL, 53 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 80.47
#
# Processing IDEX, 54 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 125.0
#
# Processing BBD, 55 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 3.5
# Implied volatility is: 56.64
#
# Processing TIGR, 56 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 3.5
# Implied volatility is: 67.97
#
# Processing T, 57 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 18.0
# Implied volatility is: 23.98
#
# Processing PLTR, 58 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 11.0
# Implied volatility is: 68.26
#
# Processing CBIO, 59 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 99.22
#
# Processing AAL, 60 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 15.0
# Implied volatility is: 53.61
#
# Processing ET, 61 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 11.0
# Implied volatility is: 39.16
#
# Processing BAC, 62 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 34.0
# Implied volatility is: 31.23
#
# Processing BNGO, 63 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.0
# Implied volatility is: 95.31
#
# Processing ONEM, 64 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 17.5
# Implied volatility is: 15.53
#
# Processing EWG, 65 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 24.0
# Implied volatility is: 28.52
#
# Processing MNMD, 66 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0.5
# Implied volatility is: 143.75
#
# Processing ANY, 67 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 1.0
# Implied volatility is: 164.06
#
# Processing BIOR, 68 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 120.31
#
# Processing RIG, 69 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.5
# Implied volatility is: 91.8
#
# Processing PFE, 70 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 50.0
# Implied volatility is: 28.22
#
# Processing MMAT, 71 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 102.34
#
# Processing C, 72 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 52.5
# Implied volatility is: 33.37
#
# Processing MULN, 73 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 178.13
#
# Processing CGC, 74 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 97.66
#
# Processing AGNC, 75 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 12.0
# Implied volatility is: 24.81
#
# Processing KO, 76 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 62.5
# Implied volatility is: 19.58
#
# Processing EVFM, 77 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 160.94
#
# Processing TLRY, 78 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 4.0
# Implied volatility is: 93.75
#
# Processing NLY, 79 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.0
# Implied volatility is: 24.61
#
# Processing PLBY, 80 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 84.86
#
# Processing NRZ, 81 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 0.0
#
# Processing NIO, 82 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 20.0
# Implied volatility is: 69.92
#
# Processing NYMT, 83 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 64.45
#
# Processing GOTU, 84 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.5
# Implied volatility is: 119.92
#
# Processing DS, 85 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 106.25
#
# Processing CTLP, 86 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.5
# Implied volatility is: 53.52
#
# Processing VRM, 87 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 147.66
#
# Processing HGEN, 88 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# HGEN, 88 not found.
# Exception is 4
# Error is: (<class 'KeyError'>, KeyError(4), <traceback object at 0x00000282FADAA7C8>)
#
# Processing AGEN, 89 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.0
# Implied volatility is: 85.16
#
# Processing ACRX, 90 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# ACRX, 90 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x00000282FADAA888>)
#
# Processing NMTR, 91 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# NMTR, 91 not found.
# Exception is 2
# Error is: (<class 'KeyError'>, KeyError(2), <traceback object at 0x00000282F8F19208>)
#
# Processing CRNT, 92 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 59.38
#
# Processing OEG, 93 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# OEG, 93 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282F946A208>)
#
# Processing THCA, 94 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# THCA, 94 not found.
# Exception is index 0 is out of bounds for axis 0 with size 0
# Error is: (<class 'IndexError'>, IndexError('index 0 is out of bounds for axis 0 with size 0'), <traceback object at 0x00000282FAC28DC8>)
#
# Processing CEI, 95 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# CEI, 95 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282FAD01D88>)
#
# Processing RIOT, 96 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 8.0
# Implied volatility is: 126.95
#
# Processing WFC, 97 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 45.0
# Implied volatility is: 33.13
#
# Processing TRX, 98 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# TRX, 98 not found.
# Exception is 10
# Error is: (<class 'KeyError'>, KeyError(10), <traceback object at 0x00000282FAD2D848>)
#
# Processing BBIG, 99 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 0.0
#
# Processing NU, 100 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 4.5
# Implied volatility is: 77.34
#
# Processing CRBP, 101 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# CRBP, 101 not found.
# Exception is 7
# Error is: (<class 'KeyError'>, KeyError(7), <traceback object at 0x00000282FAD9C848>)
#
# Processing NCLH, 102 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 12.5
# Implied volatility is: 77.93
#
# Processing TEVA, 103 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 11.0
# Implied volatility is: 43.75
#
# Processing CSCO, 104 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 45.0
# Implied volatility is: 29.0
#
# Processing KGC, 105 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.5
# Implied volatility is: 50.78
#
# Processing PINS, 106 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 22.5
# Implied volatility is: 62.5
#
# Processing BITF, 107 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 1.5
# Implied volatility is: 123.44
#
# Processing FUBO, 108 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.5
# Implied volatility is: 108.98
#
# Processing LAZR, 109 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.5
# Implied volatility is: 83.98
#
# Processing ARCC, 110 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 20.0
# Implied volatility is: 19.83
#
# Processing UAL, 111 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 38.0
# Implied volatility is: 50.64
#
# Processing GOLD, 112 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 16.0
# Implied volatility is: 39.06
#
# Processing VALE, 113 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 13.0
# Implied volatility is: 34.57
#
# Processing FTCH, 114 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 9.0
# Implied volatility is: 100.68
#
# Processing CRU, 115 of 293...
# Closest expiry is: 2022-11-18
# Closest strike price is: 10.0
# Implied volatility is: 0.78
#
# Processing CLSN, 116 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 0.0
#
# Processing DNN, 117 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 80.47
#
# Processing KMI, 118 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 17.0
# Implied volatility is: 29.0
#
# Processing NAK, 119 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0.5
# Implied volatility is: 137.5
#
# Processing NNDM, 120 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.5
# Implied volatility is: 60.16
#
# Processing TSM, 121 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 90.0
# Implied volatility is: 35.57
#
# Processing CLVS, 122 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.5
# Implied volatility is: 181.25
#
# Processing VZ, 123 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 45.0
# Implied volatility is: 20.95
#
# Processing STLA, 124 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 15.0
# Implied volatility is: 39.16
#
# Processing DNA, 125 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.0
# Implied volatility is: 89.84
#
# Processing SAN, 126 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.0
# Implied volatility is: 56.25
#
# Processing PNNT, 127 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.5
# Implied volatility is: 37.89
#
# Processing FENG, 128 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 5.0
# Implied volatility is: 164.06
#
# Processing AGCB, 129 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 56.74
#
# Processing WISH, 130 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.0
# Implied volatility is: 97.66
#
# Processing GM, 131 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 36.0
# Implied volatility is: 42.16
#
# Processing ABEO, 132 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 60.55
#
# Processing ASHR, 133 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 31.0
# Implied volatility is: 23.98
#
# Processing PARA, 134 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 25.0
# Implied volatility is: 47.61
#
# Processing HTZ, 135 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 22.5
# Implied volatility is: 52.15
#
# Processing JBLU, 136 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 9.0
# Implied volatility is: 50.98
#
# Processing BCS, 137 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 8.0
# Implied volatility is: 32.81
#
# Processing CONX, 138 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 52.73
#
# Processing XOM, 139 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 87.5
# Implied volatility is: 34.77
#
# Processing AMRN, 140 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 496.88
#
# Processing GOCO, 141 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# GOCO, 141 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282F93E7E88>)
#
# Processing CBAT, 142 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# CBAT, 142 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282F8DBC648>)
#
# Processing AM, 143 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 40.04
#
# Processing MDVL, 144 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# MDVL, 144 not found.
# Exception is 3
# Error is: (<class 'KeyError'>, KeyError(3), <traceback object at 0x00000282FAC2DE08>)
#
# Processing BITO, 145 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 14.0
# Implied volatility is: 72.36
#
# Processing DKNG, 146 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 17.5
# Implied volatility is: 73.39
#
# Processing ATY, 147 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 53.91
#
# Processing UUP, 148 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 28.0
# Implied volatility is: 13.43
#
# Processing SIRI, 149 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.0
# Implied volatility is: 30.27
#
# Processing NOK, 150 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 5.5
# Implied volatility is: 35.55
#
# Processing KWEB, 151 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 29.0
# Implied volatility is: 50.39
#
# Processing PTON, 152 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 12.0
# Implied volatility is: 118.46
#
# Processing PIPP, 153 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 4.4
#
# Processing TRVG, 154 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 67.19
#
# Processing CLOV, 155 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.5
# Implied volatility is: 100.0
#
# Processing OXY, 156 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 60.0
# Implied volatility is: 52.34
#
# Processing MPW, 157 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 16.0
# Implied volatility is: 27.88
#
# Processing ACB, 158 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 1.5
# Implied volatility is: 103.13
#
# Processing NEM, 159 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 45.0
# Implied volatility is: 37.16
#
# Processing AMRX, 160 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 87.5
#
# Processing AXU, 161 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# AXU, 161 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282FAD9CC88>)
#
# Processing HUT, 162 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 130.86
#
# Processing RUN, 163 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 35.0
# Implied volatility is: 84.38
#
# Processing GNUS, 164 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 87.5
#
# Processing CORZ, 165 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.0
# Implied volatility is: 112.89
#
# Processing TWTR, 166 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 43.0
# Implied volatility is: 56.18
#
# Processing NLOK, 167 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 24.0
# Implied volatility is: 35.21
#
# Processing DAL, 168 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 33.0
# Implied volatility is: 43.12
#
# Processing GLBS, 169 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 92.19
#
# Processing CLF, 170 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 18.0
# Implied volatility is: 61.52
#
# Processing ADVM, 171 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 50.0
#
# Processing AEM, 172 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 45.0
# Implied volatility is: 43.09
#
# Processing TEF, 173 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 48.44
#
# Processing IPOD, 174 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 10.0
# Implied volatility is: 6.25
#
# Processing GFI, 175 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 9.0
# Implied volatility is: 50.98
#
# Processing AQMS, 176 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# AQMS, 176 not found.
# Exception is 4
# Error is: (<class 'KeyError'>, KeyError(4), <traceback object at 0x00000282FA810B88>)
#
# Processing JPM, 177 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 115.0
# Implied volatility is: 28.64
#
# Processing ITUB, 178 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 5.0
# Implied volatility is: 43.36
#
# Processing EWC, 179 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 35.0
# Implied volatility is: 23.93
#
# Processing UEC, 180 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 4.5
# Implied volatility is: 78.91
#
# Processing UAMY, 181 of 293...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# UAMY, 181 not found.
# Exception is 7
# Error is: (<class 'KeyError'>, KeyError(7), <traceback object at 0x00000282FAD91808>)
#
# Processing AKBA, 182 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0.5
# Implied volatility is: 150.0
#
# Processing DM, 183 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 89.84
#
# Processing LDI, 184 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 70.31
#
# Processing BEKE, 185 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 15.0
# Implied volatility is: 86.47
#
# Processing CS, 186 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 53.13
#
# Processing TBT, 187 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 25.0
# Implied volatility is: 38.18
#
# Processing OPEN, 188 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 6.0
# Implied volatility is: 91.8
#
# Processing LUMN, 189 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 11.0
# Implied volatility is: 33.89
#
# Processing EVOK, 190 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 0.0
#
# Processing FSK, 191 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.5
# Implied volatility is: 21.68
#
# Processing BODY, 192 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 87.5
#
# Processing UNIT, 193 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 38.97
#
# Processing SKLZ, 194 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 1.5
# Implied volatility is: 108.59
#
# Processing BB, 195 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.0
# Implied volatility is: 59.57
#
# Processing CIM, 196 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 9.0
# Implied volatility is: 48.05
#
# Processing M, 197 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 18.0
# Implied volatility is: 68.56
#
# Processing CPG, 198 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 71.48
#
# Processing BRFS, 199 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 66.41
#
# Processing LFLY, 200 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 94.92
#
# Processing SWN, 201 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.0
# Implied volatility is: 65.23
#
# Processing LCID, 202 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 18.0
# Implied volatility is: 68.36
#
# Processing FCX, 203 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 30.0
# Implied volatility is: 52.78
#
# Processing BTI, 204 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 40.0
# Implied volatility is: 25.0
#
# Processing YSG, 205 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 135.94
#
# Processing DIS, 206 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 105.0
# Implied volatility is: 37.71
#
# Processing HL, 207 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 4.5
# Implied volatility is: 62.31
#
# Processing MARA, 208 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 15.0
# Implied volatility is: 131.25
#
# Processing AYRO, 209 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# AYRO, 209 not found.
# Exception is 5
# Error is: (<class 'KeyError'>, KeyError(5), <traceback object at 0x00000282FAD016C8>)
#
# Processing EFA, 210 of 293...
# Closest expiry is: 2022-09-30
# Closest strike price is: 65.0
# Implied volatility is: 21.7
#
# Processing MO, 211 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 45.0
# Implied volatility is: 21.31
#
# Processing ATUS, 212 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 11.0
# Implied volatility is: 67.68
#
# Processing XSPA, 213 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 1.0
# Implied volatility is: 117.19
#
# Processing DRRX, 214 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# DRRX, 214 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000282FA810D48>)
#
# Processing SFT, 215 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 164.06
#
# Processing GDRX, 216 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.5
# Implied volatility is: 91.41
#
# Processing BEST, 217 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 135.94
#
# Processing UXIN, 218 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 1.0
# Implied volatility is: 196.88
#
# Processing YVR, 219 of 293...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# YVR, 219 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282FABB4E08>)
#
# Processing SFL, 220 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 33.4
#
# Processing BMY, 221 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 72.5
# Implied volatility is: 23.95
#
# Processing GORO, 222 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 71.88
#
# Processing BIRD, 223 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 92.19
#
# Processing NILE, 224 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# NILE, 224 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000282FA87D348>)
#
# Processing GILT, 225 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.5
# Implied volatility is: 52.15
#
# Processing CCJ, 226 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 26.0
# Implied volatility is: 54.98
#
# Processing BP, 227 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 30.0
# Implied volatility is: 33.45
#
# Processing ATAI, 228 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 196.88
#
# Processing ALZN, 229 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# ALZN, 229 not found.
# Exception is 1
# Error is: (<class 'KeyError'>, KeyError(1), <traceback object at 0x00000282FABB41C8>)
#
# Processing FATH, 230 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 85.94
#
# Processing PLG, 231 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 2.5
# Implied volatility is: 116.41
#
# Processing FSM, 232 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.0
# Implied volatility is: 62.11
#
# Processing UDN, 233 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 18.0
# Implied volatility is: 14.65
#
# Processing ARKK, 234 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 50.0
# Implied volatility is: 57.13
#
# Processing AUY, 235 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 5.0
# Implied volatility is: 54.69
#
# Processing RNWK, 236 of 293...
# Closest expiry is: 2022-11-18
# Closest strike price is: 0
# RNWK, 236 not found.
# Exception is 6
# Error is: (<class 'KeyError'>, KeyError(6), <traceback object at 0x00000282FAC1F088>)
#
# Processing CLNE, 237 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 8.0
# Implied volatility is: 71.88
#
# Processing CLVR, 238 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# CLVR, 238 not found.
# Exception is 7
# Error is: (<class 'KeyError'>, KeyError(7), <traceback object at 0x00000282FA87D4C8>)
#
# Processing AGI, 239 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 7.5
# Implied volatility is: 58.2
#
# Processing LYFT, 240 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 20.0
# Implied volatility is: 73.1
#
# Processing AVTR, 241 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 27.5
# Implied volatility is: 34.96
#
# Processing MP, 242 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 40.0
# Implied volatility is: 59.2
#
# Processing VTNR, 243 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 15.0
# Implied volatility is: 107.91
#
# Processing CLSK, 244 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 110.16
#
# Processing GOEV, 245 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 99.61
#
# Processing KERN, 246 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 0
# KERN, 246 not found.
# Exception is 0
# Error is: (<class 'KeyError'>, KeyError(0), <traceback object at 0x00000282FAD91EC8>)
#
# Processing LVS, 247 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 40.0
# Implied volatility is: 47.95
#
# Processing BOXD, 248 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 2.5
# Implied volatility is: 169.53
#
# Processing MRO, 249 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.0
# Implied volatility is: 55.96
#
# Processing TTOO, 250 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 0
# TTOO, 250 not found.
# Exception is 11
# Error is: (<class 'KeyError'>, KeyError(11), <traceback object at 0x00000282FAD91A08>)
#
# Processing STWD, 251 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 23.0
# Implied volatility is: 29.88
#
# Processing CVE, 252 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 16.0
# Implied volatility is: 56.45
#
# Processing RKT, 253 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 9.99
# Implied volatility is: 52.54
#
# Processing HMLP, 254 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 6.25
#
# Processing GBT, 255 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 50.0
# Implied volatility is: 84.52
#
# Processing ACWI, 256 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 90.0
# Implied volatility is: 21.29
#
# Processing NEOG, 257 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.5
# Implied volatility is: 65.38
#
# Processing KRTX, 258 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 140.0
# Implied volatility is: 131.06
#
# Processing CSTM, 259 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 14.0
# Implied volatility is: 51.95
#
# Processing STEM, 260 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 15.0
# Implied volatility is: 85.01
#
# Processing AES, 261 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 24.0
# Implied volatility is: 39.94
#
# Processing DASH, 262 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 80.0
# Implied volatility is: 68.85
#
# Processing TWLO, 263 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 85.0
# Implied volatility is: 66.3
#
# Processing TIP, 264 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 115.0
# Implied volatility is: 9.37
#
# Processing TEAM, 265 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 270.0
# Implied volatility is: 53.24
#
# Processing NOVA, 266 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 30.0
# Implied volatility is: 79.13
#
# Processing CEG, 267 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 75.0
# Implied volatility is: 61.16
#
# Processing PACB, 268 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 6.0
# Implied volatility is: 230.66
#
# Processing CVNA, 269 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 45.0
# Implied volatility is: 118.85
#
# Processing MMM, 270 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 145.0
# Implied volatility is: 22.43
#
# Processing EXPE, 271 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 105.0
# Implied volatility is: 50.07
#
# Processing DUK, 272 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 110.0
# Implied volatility is: 17.57
#
# Processing DOCS, 273 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 37.5
# Implied volatility is: 64.99
#
# Processing YETI, 274 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 45.0
# Implied volatility is: 50.44
#
# Processing GPRO, 275 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 7.0
# Implied volatility is: 50.39
#
# Processing APDN, 276 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 5.0
# Implied volatility is: 155.47
#
# Processing ARRY, 277 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 17.5
# Implied volatility is: 96.68
#
# Processing FTNT, 278 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 54.0
# Implied volatility is: 47.36
#
# Processing MQ, 279 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 11.0
# Implied volatility is: 85.45
#
# Processing NET, 280 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 75.0
# Implied volatility is: 78.14
#
# Processing PFSI, 281 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 55.0
# Implied volatility is: 37.82
#
# Processing RDFN, 282 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 10.0
# Implied volatility is: 90.23
#
# Processing NLSN, 283 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 23.0
# Implied volatility is: 83.3
#
# Processing DDOG, 284 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 115.0
# Implied volatility is: 67.09
#
# Processing MNST, 285 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 90.0
# Implied volatility is: 30.26
#
# Processing K, 286 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 75.0
# Implied volatility is: 20.73
#
# Processing HST, 287 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 18.0
# Implied volatility is: 40.23
#
# Processing BKKT, 288 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 3.0
# Implied volatility is: 110.16
#
# Processing SOXL, 289 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 22.0
# Implied volatility is: 96.0
#
# Processing CDEV, 290 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 6.0
# Implied volatility is: 67.97
#
# Processing BIG, 291 of 293...
# Closest expiry is: 2022-10-21
# Closest strike price is: 22.5
# Implied volatility is: 64.5
#
# Processing SKT, 292 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 16.0
# Implied volatility is: 50.1
#
# Processing BYND, 293 of 293...
# Closest expiry is: 2022-09-16
# Closest strike price is: 40.0
# Implied volatility is: 75.59

# %%
print('Completed.')
# Out:
# Completed.

# %% [markdown]
# Create a dataframe for the implied volatility data.

# %%
iv_dictionary = {
    'ticker':ticker_list2,
    'expiry':expiry_list,
    'strike':strike_list,
    'implied_vol':iv_list
}

iv_df = pd.DataFrame(iv_dictionary)
iv_df["implied_vol"] = iv_df["implied_vol"].astype(str).astype(float)
iv_df = iv_df.sort_values(['implied_vol'],ascending=False)
iv_df.to_csv('../0_data_dump/optionistics/implied_vols.csv')
iv_df.head(3)
# Out:
#     ticker      expiry  strike  implied_vol
# 129   AMRN  2022-10-21     1.0       496.88
# 242   PACB  2022-10-21     6.0       230.66
# 199   UXIN  2022-09-16     1.0       196.88

# %%
print('Completed.')
# Out:
# Completed.

# %%
final_df = pd.merge(cheap_df,finviz_df,on='ticker',how='outer')
final_df = pd.merge(final_df,optionistics_data,on='ticker',how='outer')
final_df = pd.merge(final_df,iv_df,on='ticker',how='outer')
final_df['iv_premium'] = final_df['implied_vol'] - final_df['realized_vol']

final_df['iv_prem_pt'] = 0
final_df['iv_prem_pt'] = np.select(condlist=[(final_df['iv_premium']>final_df['iv_premium'].quantile(0.85))],
                           choicelist=[1],
                           default=0)

final_df['oi_pct_chg_pts'] = final_df['oi_pct_chg_pts'].fillna(0)
final_df['cheap_pt'] = final_df['cheap_pt'].fillna(0)
final_df['total_pts'] = final_df['cheap_pt'] + final_df['float_short_pt'] + final_df['oi_pct_chg_pts'] + final_df['iv_prem_pt']
final_df = final_df[['ticker','expiry','strike','total_pts','iv_prem_pt','cheap_pt','oi_pct_chg_pts','float_short_pt','iv_premium','avg_pct','float_short','oi_pct_chg','p_c_ratio']]
final_df = final_df.sort_values(by = ['total_pts','float_short'],ascending=[False,False])
final_df = final_df[final_df['total_pts'] > 0]
final_df.to_csv('../0_data_dump/asset_screener/options_output.csv')
final_df.head(20)
# Out:
#     ticker      expiry  strike  total_pts  iv_prem_pt  cheap_pt  \
# 26    BKKT  2022-09-16    3.00        3.0           0       1.0
# 209   PACB  2022-10-21    6.00        3.0           1       0.0
# 9     DOCS  2022-09-16   37.50        3.0           0       1.0
# 15    PLBY  2022-10-21    7.50        3.0           1       1.0
# 25    BIRD  2022-09-16    5.00        3.0           1       1.0
# 23    BIOR  2022-10-21    1.00        3.0           1       1.0
# 20    MNMD  2022-09-16    0.50        3.0           1       1.0
# 225   BYND  2022-09-16   40.00        2.0           0       0.0
# 230   CVNA  2022-10-21   45.00        2.0           0       0.0
# 149    BIG  2022-10-21   22.50        2.0           0       0.0
# 132    RKT  2022-09-16    9.99        2.0           0       0.0
# 32    SIRI  2022-10-21    7.00        2.0           0       1.0
# 253   RIOT  2022-09-16    8.00        2.0           1       0.0
# 69    GDRX  2022-10-21    7.50        2.0           1       0.0
# 283   ATUS  2022-10-21   11.00        2.0           0       0.0
# 264   CDEV  2022-10-21    6.00        2.0           0       0.0
# 237   COIN  2022-10-21   95.00        2.0           0       0.0
# 198    SFT  2022-09-16    2.50        2.0           1       0.0
# 54    CLSK  2022-09-16    5.00        2.0           1       0.0
# 224   NOVA  2022-10-21   30.00        2.0           0       0.0
#
#      oi_pct_chg_pts  float_short_pt  iv_premium  avg_pct  float_short  \
# 26              1.0             1.0       -4.41   -17.16        33.20
# 209             1.0             1.0      118.19   126.31        17.59
# 9               1.0             1.0       -9.79   -70.96        16.90
# 15              0.0             1.0       15.17   -42.93        15.08
# 25              0.0             1.0       12.06   -17.77        13.14
# 23              0.0             1.0       34.84   -20.48        10.85
# 20              0.0             1.0       63.12   -24.46         8.67
# 225             1.0             1.0      -38.89   133.73        37.13
# 230             1.0             1.0      -51.03   137.15        37.01
# 149             1.0             1.0       -9.97    91.78        35.19
# 132             1.0             1.0       -5.20    86.42        30.44
# 32              0.0             1.0        7.65   -10.08        26.51
# 253             0.0             1.0       15.77   163.88        26.40
# 69              0.0             1.0       15.32    48.48        24.53
# 283             1.0             1.0      -31.74   324.55        20.11
# 264             1.0             1.0       -8.77   184.48        19.91
# 237             1.0             1.0      -42.82   144.45        19.39
# 198             0.0             1.0       42.91   117.85        19.38
# 54              0.0             1.0       12.81    34.76        17.83
# 224             1.0             1.0      -26.89   132.56        17.62
#
#      oi_pct_chg  p_c_ratio
# 26         8.06       0.47
# 209       15.63       0.71
# 9         13.31       0.98
# 15          NaN        NaN
# 25          NaN        NaN
# 23          NaN        NaN
# 20          NaN        NaN
# 225        6.97       1.50
# 230       14.65       0.77
# 149        7.53       0.78
# 132        9.95       1.13
# 32          NaN        NaN
# 253         NaN        NaN
# 69          NaN        NaN
# 283       14.45       1.01
# 264        7.67       0.54
# 237       11.31       1.28
# 198         NaN        NaN
# 54          NaN        NaN
# 224       15.80       1.06

# %%
print(f'Completed on {datetime.datetime.now()}.')
# Out:
# Completed on 2022-08-06 23:03:36.037038.
